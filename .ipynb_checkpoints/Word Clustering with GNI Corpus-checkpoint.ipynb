# %% [markdown]
# # Abstract
#
#  Word2Vec을 활용하여 연도별로 GNI 코퍼스 내의 keywords들을 Clusturing한다.

# %%
# import nltk
import nltk
from nltk.corpus import *
from nltk import *

# libraries for word clustering
from gensim.models import Word2Vec
from sklearn.cluster import KMeans
import joblib

# import libraries for preprocessing
from nltk import RegexpTokenizer
import re

import os
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.manifold import MDS
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

import time

# %%
# using sentence tokenized gni corpus.
corpus_root = 'C:/Users/Maeg/nltk_data/Genomics-Informatics-Corpus-master/Genomics-Informatics-Corpus-master/GNI Corpus 1.0/sentence_tokenized'
GNIcorpus = PlaintextCorpusReader(corpus_root,'.*\.txt',encoding='utf-8')

# %% [markdown]
# # 전처리

# %%
# preprocessing each sentence
def gni_preprocessed_sents(gni_sents):
    
    # load stopwords and initialize preprocessed sentences list
    stops = set(stopwords.words("english"))
    gni_pre_sents = []
    # remove non-letter words and stop words in each sentence
    for s in gni_sents :
        sent = []
        for w in s :
            if (re.match(r'[a-zA-Z0-9]+',w) !=  None) & (not w in stops) :
                sent.append(w.lower())
        gni_pre_sents.append(sent)
    
    # return preprocessed sentences list
    return gni_pre_sents

# %%
# preprocessing GNI corpus
print("Start preprocessing... : G&I sentences")
gni_sents = gni_preprocessed_sents(GNIcorpus.sents())
print("End preprocessing: G&I sentences")
# Out:
# Start preprocessing... : G&I sentences
# End preprocessing: G&I sentences

# %% [markdown]
# # Modeling and Training Word2Vec

# %%
n_features = 300       # the number of Word2Vector Dimension
min_wordcount = 40     # Words which counts at least 20 times are available
n_workers = 4          # the number of parallel work
size_boundary = 10      # contextual window size
downsampling = 1e-3    # down sampling with frequent words

# Initialize and train Word2Vec model
print("Start Training ...")
model = Word2Vec(gni_sents,
                 workers = n_workers,
                 size = n_features,
                 min_count = min_wordcount,
                 window = size_boundary,
                 sample = downsampling)
print("End Training ")

# manage memory
model.init_sims(replace=True)

# save trained model
model.save("GNI_"+str(n_features)+"features_"+str(min_wordcount)+"minwords_"+str(size_boundary)+"window")
# Out:
# Start Training ...
# End Training

# %% [markdown]
# # Word Clustering
#
# Word2Vec으로 얻은 각 단어의 word vector를 이용하여 word cluster한다.

# %%
# clustering start time
start = time.time()
print("Start: Clustering")

# word vector of word2Vec model
gniwv = model.wv

# set the number of cluster
num_clusters = (int)(len(gniwv.vocab) / 5)

# Initialize a k-means object and use it to extract centroids(cluster)
kmeans_clustering = KMeans( n_clusters = num_clusters)
index = kmeans_clustering.fit_predict(gniwv.vectors)

end = time.time()
clustering_time = end - start
print("End  : Clustering")

# print Clustering information
print("\n============== Clustering Information ==============")
print("Clustering time:", clustering_time)
print("# of Word vectors:", len(gniwv.vocab))
print("# of Clusters:", num_clusters)
# Out:
# Start: Clustering
# End  : Clustering
#
# ============== Clustering Information ==============
# Clustering time: 66.80735421180725
# # of Word vectors: 2327
# # of Clusters: 465

# %%
# save the cluster models
joblib.dump(kmeans_clustering, 'GNI_words_cluster.pkl')
# Out:
# ['GNI_words_cluster.pkl']

# %%
# word - cluster number matching
word_centroid_map = dict(zip(gniwv.index2word, index))

# %%
for cluster in range(num_clusters) :
    print('\nCluster',cluster)
    words = []
    for k, c in word_centroid_map.items():
        if c == cluster :
            words.append(k)
    print(words)
# Out:
# Cluster 0
# ['right', 'separated', 'u', 'product', 'tank']
#
# Cluster 1
# ['largely', 'consequently', 'reason', 'share', 'regarded', 'understood']
#
# Cluster 2
# ['cell', 'cells', 'ii', 'cycle']
#
# Cluster 3
# ['statistics', 'measurements', 'weighted', 'characteristic', 'roc', 'correction', 'rank', 'receiver']
#
# Cluster 4
# ['research', 'health']
#
# Cluster 5
# ['approach', 'use', 'possible', 'knowledge', 'approaches', 'experimental', 'computational', 'make', 'necessary', 'mining', 'efficient']
#
# Cluster 6
# ['seven', 'cows', '62', 'appeared', '63', 'half']
#
# Cluster 7
# ['unique', 'homologous', 'eukaryotic', 'encoded', 'transcribed', 'nucleosome']
#
# Cluster 8
# ['detailed', 'evaluation', 'employed', 'framework', 'created', 'combining', 'popular', 'overview', 'fast', 'iabio', 'visual', 'interactive']
#
# Cluster 9
# ['bmi', 'sex', 'heritability', 't1dm', 'fulminant']
#
# Cluster 10
# ['proteins', 'binding', 'active', 'membrane', 'zinc', 'bind', 'complexes', 'interact', 'interacting', 'stability', 'folding', 'ama1', 'catalytic', 'finger']
#
# Cluster 11
# ['peg3', 'co', 'localization', 'translational', 'translation', 'hp1', 'cis']
#
# Cluster 12
# ['they', 'affect', 'likely', 'certain', 'affected', 'influence', 'explain', 'causal', 'affecting']
#
# Cluster 13
# ['produced', 'extracted', 'point', 'hybridization', 'preparation', 'collection', 'rice', 'digital', 'prepared', 'libraries', 'hybrid']
#
# Cluster 14
# ['software', 'program', 'web', 'server']
#
# Cluster 15
# ['decrease', 'smoking', 'hepatitis', 'cad', 'alcohol', 'aspirin', 'concentrations', 'oral', 'consumption', 'vpa', 'ht', 'adrs']
#
# Cluster 16
# ['examined', 'confirmed', 'mtdna', 'consistently']
#
# Cluster 17
# ['asian', 'larger', 'cattle', 'sizes', 'breeds', 'ancestry', 'east']
#
# Cluster 18
# ['required', 'limited', 'advances', 'wes', 'technical']
#
# Cluster 19
# ['clusters', 'side', 'composed', 'intermediate']
#
# Cluster 20
# ['third', 'instead', 'both', 'degree', 'points', 'internal', 'figure', 'separate', 'assessed', 'comparisons']
#
# Cluster 21
# ['genotype', 'included', 'five', 'genotypes', 'hanwoo', 'holstein', 'imputed', 'haplotypes']
#
# Cluster 22
# ['either', 'resulting', 'distinct', 'mutated', 'hypermethylation']
#
# Cluster 23
# ['together', 'global', 'soil', 'complexity', 'sources', 'compositional', 'characterization', 'proteomic', 'signatures']
#
# Cluster 24
# ['plot', 'mean', 'j', 'confidence', 'ci', 'deviation', 'root', 'q', 'mig']
#
# Cluster 25
# ['treatment', 'early', 'conditions', 'diagnosis', 'therapy', 'prognosis', 'prevention', 'pdx']
#
# Cluster 26
# ['our', 'determine', 'difficult', 'detecting', 'investigate', 'evaluate', 'interpretation', 'validate', 'aimed', 'assess']
#
# Cluster 27
# ['nc', 'young', 'diagnosed']
#
# Cluster 28
# ['kb', 'around', 'sense', 'ends', 'mer']
#
# Cluster 29
# ['scientific', 'articles', 'informatics', 'corpus', 'science', 'article']
#
# Cluster 30
# ['investigated', 'gwass', 'medication', 'adherence']
#
# Cluster 31
# ['changes', 'loss', 'suggesting', 'suppressor', 'abnormal', 'altered', 'oncogenes']
#
# Cluster 32
# ['coli', 'japonicum', 'o']
#
# Cluster 33
# ['means', 'sub', 'phylogenetic', 'contiguous', 'code', 'name', 'taxonomic', 'maximal', 'suffix']
#
# Cluster 34
# ['loci', 'traits', 'phenotype', 'bmd', 'trait', 'associations', 'ethnicity']
#
# Cluster 35
# ['important', 'role', 'potential', 'mechanisms', 'processes', 'mechanism', 'roles', 'essential', 'play', 'lead', 'key', 'critical', 'plays', 'crucial', 'physiological']
#
# Cluster 36
# ['20', 'respectively', 'approximately']
#
# Cluster 37
# ['lung', 'cancers', 'liver', 'tumors', 'kidney', 'atc', 'colorectal', 'prostate', 'carcinoma', 'acute', 'colon', 'leukemia', 'solid', 'developmental', 'thyroid', 'renal', 'pancreatic']
#
# Cluster 38
# ['regions', 'introns', 'intron']
#
# Cluster 39
# ['collected', 'tcga']
#
# Cluster 40
# ['commonly', 'because', 'rather', 'quite', 'sufficient', 'but', 'spectrum', 'little', 'background', 'examine', 'inter', 'unlike']
#
# Cluster 41
# ['protein', 'predicted']
#
# Cluster 42
# ['detection', 'microarray', 'profiles', 'profiling']
#
# Cluster 43
# ['accuracy', 'validation', 'cross', 'procedures', 'procedure', 'compare', 'robust']
#
# Cluster 44
# ['retrieved', 'strain', 'string', 'uniprot']
#
# Cluster 45
# ['illumina', 'sequenced', 'paired']
#
# Cluster 46
# ['novel', 'recently', 'understanding', 'future', 'understand', 'help', 'become', 'focused', 'importance', 'numerous']
#
# Cluster 47
# ['snps', 'single', 'nucleotide', 'polymorphisms', 'polymorphism']
#
# Cluster 48
# ['bed', 'aligned', 'processed', 'bam']
#
# Cluster 49
# ['showed', 'levels', 'observed', 'significantly']
#
# Cluster 50
# ['regulated', 'kdo', 'ifn', 'inhibition', 'activated', 'upregulated', 'inhibitor', 'br', 'pten', 'tnf', 'stimulation', '1β']
#
# Cluster 51
# ['support', 'introduced', 'task', 'services', 'pubmed', 'bionlp', 'fields', 'standards', 'documents', 'publications', 'nlp']
#
# Cluster 52
# ['27', '29', '31', '32', '38', '39', '46', 'il', '43', '44', '47']
#
# Cluster 53
# ['5', '10', '6', '8', '7']
#
# Cluster 54
# ['pharmacophore']
#
# Cluster 55
# ['used', 'applied', 'step', 'steps', 'packages']
#
# Cluster 56
# ['95', 'fold', 'vs', 'mg', 'dl']
#
# Cluster 57
# ['made', 'widely', 'multi', 'problem', 'here', 'analyze', 'accurate', 'allows', 'reliable', 'analyzing', 'purpose', 'must', 'powerful', 'easy', 'goal', 'allow', 'require', 'traditional', 'advantage', 'advantages', 'limitation', 'enables', 'apply', 'adopted', 'analytical', 'integrative', 'enable', 'expect', 'aim']
#
# Cluster 58
# ['fig', 'shows']
#
# Cluster 59
# ['64', 'mol', '75', 'kcal', '85', '79']
#
# Cluster 60
# ['significant', 'show', 'correlation', 'correlations', 'phenotypic', 'statistically']
#
# Cluster 61
# ['pattern', 'codon', 'codons', 'usage', 'bias']
#
# Cluster 62
# ['expression', 'level', 'differential']
#
# Cluster 63
# ['written', 'consent', 'cma', 'informed']
#
# Cluster 64
# ['usa', 'ca', 'kit', 'assay', 'manufacturer', 'fisher', 'instructions', 'qiagen', 'clara', 'san', 'diego']
#
# Cluster 65
# ['to', 'multiple', 'detect']
#
# Cluster 66
# ['forms', 'namely', 'nine', 'observation', 'ofloxacin', 'trans', 'curcumin', 'rif']
#
# Cluster 67
# ['profile', 'manner', 'peptides', 'occurs', 'stem', 'light', 'coupled']
#
# Cluster 68
# ['indels', 'heterozygous', 'polymorphic', 'snvs']
#
# Cluster 69
# ['taken', 'efficiency', 'upon', 'nature', 'subsequently', 'adaptation', 'speed', 'mode', 'capable']
#
# Cluster 70
# ['process', 'structural', 'predict']
#
# Cluster 71
# ['score', 'distance', 'k', 'scores', 'follows', 'z', 'probability']
#
# Cluster 72
# ['identification', 'especially', 'diverse', 'often', 'interest', 'epigenomic']
#
# Cluster 73
# ['flow', 'yield', 'concordance', 'consisted']
#
# Cluster 74
# ['for']
#
# Cluster 75
# ['sites', 'transcripts', 'promoters', 'faire', 'h3k4me3', 'h3k9', 'h3k4me1']
#
# Cluster 76
# ['known', 'caused', 'discovered', 'causing']
#
# Cluster 77
# ['addition']
#
# Cluster 78
# ['if', 'combination', 'shared', 'consider', 'predictions', 'define', 'get', 'select', 'continuous', 'meaningful', 'infer']
#
# Cluster 79
# ['across']
#
# Cluster 80
# ['list', 'kegg', 'encyclopedia', 'kyoto']
#
# Cluster 81
# ['cannot', 'enough', 'take', 'account', 'makes', 'hard', 'aims', 'actual', 'completely']
#
# Cluster 82
# ['bp', 'length', '200', 'state', 'units', 'count', 'unit']
#
# Cluster 83
# ['i', 'containing', 'terminal']
#
# Cluster 84
# ['project', 'published', 'international', 'consortium']
#
# Cluster 85
# ['linear', 'variance', 'likelihood', 'slr']
#
# Cluster 86
# ['heart', 'resistant', 'mortality']
#
# Cluster 87
# ['variable', 'pair', 'represents', 'maximum', 'plots', 'minimum', 'fixed', 'parameter', 'pairwise', 'removing']
#
# Cluster 88
# ['high', 'low']
#
# Cluster 89
# ['components', 'supported', 'recognition', 'central', 'hence', 'dynamics', 'ape1', 'theory', 'influenza', 'zikv', 'towards']
#
# Cluster 90
# ['rpob', 'affinity', 'na', 'kir6', 'hydrophobic']
#
# Cluster 91
# ['mapping', 'ms', 'original', 'algorithms', 'filtering', 'calling', 'qc', 'arrays']
#
# Cluster 92
# ['isolated', 'culture', 'peripheral']
#
# Cluster 93
# ['specific', 'patterns']
#
# Cluster 94
# ['15', '16', '18', '17', '19']
#
# Cluster 95
# ['frequency', 'allele', 'frequencies', 'minor', 'greater', 'maf']
#
# Cluster 96
# ['by', 'programs', 'concept', 'construction', 'easily', 'subsequent', 'correct', 'through', 'construct', 'assays', 'window', 'vectors', 'storage', 'remove', 'formats', 'create']
#
# Cluster 97
# ['x', 'd', 's', 'position', 'f', 'l', 'm', 'v']
#
# Cluster 98
# ['generally', 'chromosomal', 'majority', 'occur', 'exist', 'functionally', 'rearrangements', 'alteration']
#
# Cluster 99
# ['receptors', 'members', 'virulence', 'iron', 'member', 'biosynthesis', 'encodes', 'baumannii', 'acinetobactin']
#
# Cluster 100
# ['involved', 'regulation', 'functions', 'pathways', 'cellular', 'signaling', 'metabolism']
#
# Cluster 101
# ['mouse', 'induced', 'anti', 'apoptosis', 'proliferation', 'brain', 'nimbolide', 'invasion', 'metastasis', 'pkd2', 'epithelial', 'death']
#
# Cluster 102
# ['measured', 'concentration']
#
# Cluster 103
# ['1', '2', '3', '4']
#
# Cluster 104
# ['transcriptome', 'encode', 'de', 'assembly', 'novo']
#
# Cluster 105
# ['reverse', 'molecule', 'loop', 'double', 'precursor', 'motif', 'mature', 'gyrase', 'cleavage']
#
# Cluster 106
# ['terms', 'go']
#
# Cluster 107
# ['conclusion', 'words', 'section', 'authors', 'confirm', 'regard', 'describe', 'demonstrate']
#
# Cluster 108
# ['tc', 'color', 'fdr', 'ranked', 'cutoff']
#
# Cluster 109
# ['clear', 'condition', 'period', 'clearly', 'prevalent', 'western', 'severe', 'remained', 'morphology']
#
# Cluster 110
# ['hits', '3d', 'ion', 'subjected', 'backbone', 'md', 'refined']
#
# Cluster 111
# ['ngs', 'next', 'generation', 'technology', 'technologies', 'targeted', 'throughput', 'cost']
#
# Cluster 112
# ['dna']
#
# Cluster 113
# ['age', 'women', 'children', 'men']
#
# Cluster 114
# ['model', 'prediction', 'models']
#
# Cluster 115
# ['these', 'although', 'suggest', 'findings', 'biomarkers', 'underlying']
#
# Cluster 116
# ['pre', 'stored', 'bio', 'portal', 'mysql', 'keywords', 'ictv', 'uk', 'ivag']
#
# Cluster 117
# ['survival', 'gastric', 'pressure', 'bone', 'lymphoma']
#
# Cluster 118
# ['pcr', 'amplification', 'polymerase', 'reaction', 'cdna']
#
# Cluster 119
# ['information', 'annotation', 'tool', 'databases', 'search', 'annotations']
#
# Cluster 120
# ['total', '000', '100', 'per', 'million', '500']
#
# Cluster 121
# ['identified', 'reported', 'previously']
#
# Cluster 122
# ['evolution', 'tes', 'instability']
#
# Cluster 123
# ['groups', 'gender']
#
# Cluster 124
# ['te', 'enhancers', 'marks', 'noncoding']
#
# Cluster 125
# ['detected']
#
# Cluster 126
# ['real']
#
# Cluster 127
# ['combined', 'independent', 'meta', 'catalog', 'gwa']
#
# Cluster 128
# ['directly', 'view', 'deep', 'technique', 'metagenome', 'proteome', 'maps', 'involves', 'msdna']
#
# Cluster 129
# ['sequences', 'sequence']
#
# Cluster 130
# ['yet', 'particularly', 'far', 'investigation', 'great', 'give', 'helpful', 'aspects']
#
# Cluster 131
# ['mir', '21', '3p']
#
# Cluster 132
# ['site', 'exon', 'exons', 'upstream', 'utr', 'flanking', 'tss']
#
# Cluster 133
# ['study', 'previous']
#
# Cluster 134
# ['lipid', 'strongly', 'correlated', 'lpl', 'klf5', 'lef1']
#
# Cluster 135
# ['followed', '150', 'barcodes', 'gel', 'volume', 'gb', '96', 'buffer', 'extension', 'mixture', 'electrophoresis', 'oligonucleotides']
#
# Cluster 136
# ['considered', 'optimal', 'reduction', 'hypothesis', 'subject']
#
# Cluster 137
# ['four']
#
# Cluster 138
# ['aml', 'ovarian']
#
# Cluster 139
# ['mass', 'grs', 'bmr', 'odds', 'null', 'tt', 'gstm1']
#
# Cluster 140
# ['gene', 'enrichment']
#
# Cluster 141
# ['testing', 'admixture', 'dtc']
#
# Cluster 142
# ['al']
#
# Cluster 143
# ['further', 'architecture', 'neuropeptides', 'recognized', 'possibility', 'thereby', 'accessibility', 'serve', 'besides', 'dynamic', 'explored']
#
# Cluster 144
# ['new', 'microbial', 'systems', 'biology', 'life', 'techniques', 'metagenomic', 'comprehensive', 'metagenomics', 'omics', 'advanced']
#
# Cluster 145
# ['statistical', 'power', 'false', 'tests', 'estimate', 'estimates', 'missing']
#
# Cluster 146
# ['facial', 'mets', 'conventional', 'predictive', 'physical', 'outcome', 'lifestyle']
#
# Cluster 147
# ['studied', 'ability', 'mentioned', 'led', 'remains', 'proven', 'contribution', 'kimchi', 'involving', 'substantial', 'action', 'promising', 'fully']
#
# Cluster 148
# ['stable', 'sensitive', 'rt', 'reactions', 'exhibited', 'antibody']
#
# Cluster 149
# ['wide']
#
# Cluster 150
# ['throughout', 'portion', 'largest', 'ancestral', 'divergence', 'carry']
#
# Cluster 151
# ['corresponding', 'red', 'blue']
#
# Cluster 152
# ['database', 'ncbi', 'downloaded', 'gov', 'nih', 'nlm', 'online']
#
# Cluster 153
# ['proposed', 'classification', 'main', 'way', 'learning', 'machine', 'semantic']
#
# Cluster 154
# ['rna', 'seq', 'chip']
#
# Cluster 155
# ['whereas', '34', '42', '41', '56', '55', '53', '54', '58', '61', '59', 'antigen', '83']
#
# Cluster 156
# ['individual', 'differences', 'expected', 'much', 'relatively']
#
# Cluster 157
# ['promoter', 'cpg', 'methylated', 'cgis']
#
# Cluster 158
# ['major', 'cause', 'leading', 'causes', 'differentiation']
#
# Cluster 159
# ['among']
#
# Cluster 160
# ['of', 'milk', 'autosomal', 'akt2', 'nonsynonymous', 'akt3']
#
# Cluster 161
# ['increase', 'kd', 'year', 'months', 'prevalence', 'incidence', 'younger']
#
# Cluster 162
# ['validated', 'animals', 'oncochase']
#
# Cluster 163
# ['version', 'plink']
#
# Cluster 164
# ['clustering', 'carried', 'hierarchical']
#
# Cluster 165
# ['integrated', 'processing', 'pipeline', 'experiments', 'platforms', 'requires', 'perform', 'workflow']
#
# Cluster 166
# ['annotated', 'blast', 'query', 'genbank', 'accession']
#
# Cluster 167
# ['one']
#
# Cluster 168
# ['candidates', 'biomarker', 'predicting', 'deps']
#
# Cluster 169
# ['dataset', 'all', 'genotyping', 'panel', 'hapmap', 'genotyped']
#
# Cluster 170
# ['families', 'classified', 'classes', 'downstream', 'categories', 'motifs', 'encoding', 'imprinted', 'conservation']
#
# Cluster 171
# ['matched', 'fluid', 'cfdna', 'urine', 'transplant']
#
# Cluster 172
# ['49', '57', '68', 'ns', 'others', '66', '67', '89', '71', '86', '92', '78', '88']
#
# Cluster 173
# ['pairs', 'estimated', 'alleles', 'substitution', 'proportion', 'explained']
#
# Cluster 174
# ['ago', 'leu', 'ala', 'phe', 'tyr', 'val']
#
# Cluster 175
# ['biological', 'functional', 'network', 'relationships', 'networks']
#
# Cluster 176
# ['chromosomes', 'strains', 'sva', 'plants']
#
# Cluster 177
# ['et']
#
# Cluster 178
# ['including', 'well']
#
# Cluster 179
# ['representative', 'consisting', 'no', 'parts', 'distributed']
#
# Cluster 180
# ['additional', 'with', 'already', 'genetics', 'limitations', 'discover', 'efforts', 'date', 'successful', 'enabled']
#
# Cluster 181
# ['identify', 'candidate', 'find', 'identifying']
#
# Cluster 182
# ['need', 'environment', 'needed', 'microbiome', 'needs', 'strategy', 'regarding', 'problems', 'strategies', 'appropriate', 'focus', 'develop', 'issues', 'overcome', 'challenges', 'challenge', 'explore', 'practice', 'scientists']
#
# Cluster 183
# ['block', 'hla', 'ld', 'blocks', 'haplotype', 'linkage', 'disequilibrium']
#
# Cluster 184
# ['http', 'www', 'org', 'https', 'edu', 'com', 'ac']
#
# Cluster 185
# ['current', 'effective']
#
# Cluster 186
# ['two', 'three']
#
# Cluster 187
# ['japanese', 'cohorts', 'participants', 'european', 'chinese', 'ansan', 'recruited', '842', 'south']
#
# Cluster 188
# ['kr', 'er', 'ns3', 'docked', 'phosphoglucosamine', 'mutase', 'substrate']
#
# Cluster 189
# ['frequently', 'organisms', 'mammalian', 'signature', 'mammals', 'occurring', 'nucleus', 'organism', 'endogenous']
#
# Cluster 190
# ['described']
#
# Cluster 191
# ['activity', 'activation', 'dependent', 'formation', 'kinase', 'nf', 'p53', 'surface', 'phosphorylation']
#
# Cluster 192
# ['memory', 'full', 'word', 'page', 'converted', 'java', 'website']
#
# Cluster 193
# ['elements', 'coding', 'long', 'alu', 'deletion', 'recombination', 'rnas', 'insertion']
#
# Cluster 194
# ['example']
#
# Cluster 195
# ['number', 'small', 'copy']
#
# Cluster 196
# ['mitochondrial', 'insertions', 'deletions', 'transposable', 'inserted', 'copies', 'duplication']
#
# Cluster 197
# ['after', 'final', 'removed', 'filtered', 'peak', 'gatk']
#
# Cluster 198
# ['variants', 'variations', 'variation', 'rare']
#
# Cluster 199
# ['reference', 'reads', 'read', 'end', 'base', 'coverage', 'mapped', 'resolution']
#
# Cluster 200
# ['issue', 'introduction']
#
# Cluster 201
# ['results', 'result']
#
# Cluster 202
# ['stage', 'history', 'crc', 'gastritis', 'gdm', 't2dm', 'people', 'sle', 'coronary']
#
# Cluster 203
# ['along', 'occurrence', 'respect', 'location', 'genus', 'contained', 'repeated', 'seed', 'codes', 'fish']
#
# Cluster 204
# ['mediated', 'transcriptional', 'silencing', 'regulate', 'repair', 'damage']
#
# Cluster 205
# ['second', 'training', 'binary', 'blup', 'calculation', 'bayesian', 'principal', 'calculate', 'partition']
#
# Cluster 206
# ['regulatory', 'epigenetic', 'alternative', 'splicing', 'hotair']
#
# Cluster 207
# ['states', 'transcript', 'start', 'strand', 'stranded', 'dnase', 'tandem', 'reading']
#
# Cluster 208
# ['negative', 'mrp2', 'lipoprotein', 'intake']
#
# Cluster 209
# ['hearing', 'chromothripsis', 'poor', 'cardiovascular', 'hbv']
#
# Cluster 210
# ['evaluated', 'lasso', 'estimation', 'pca', 'standardized', 'estimating', 'permutation', 'multivariate']
#
# Cluster 211
# ['case', 'subjects', 't2d']
#
# Cluster 212
# ['true', 'smaller', 'fst', 'platelet', 'heterozygosity', 'assumption']
#
# Cluster 213
# ['copd', 'stages', '27a', 'g64']
#
# Cluster 214
# ['expressed', 'highly', 'differentially']
#
# Cluster 215
# ['selected', 'top']
#
# Cluster 216
# ['data', 'datasets']
#
# Cluster 217
# ['30', '50', '40', 'h', '60', 'min', '80', 'mm', '70']
#
# Cluster 218
# ['distribution', 'indicates', 'y', 'axis']
#
# Cluster 219
# ['last', '2013', 'orcid', 'released']
#
# Cluster 220
# ['given', 'map', 'entire', 'rrna', '16s', 'consensus', 'alignments']
#
# Cluster 221
# ['properties', 'chemical']
#
# Cluster 222
# ['present']
#
# Cluster 223
# ['lines', 'line']
#
# Cluster 224
# ['target', 'mrna', 'mrnas']
#
# Cluster 225
# ['as']
#
# Cluster 226
# ['consistent', 'metastatic', 'cnas', 'distinguish', 'pc', 'circulating', 'tp53', 'xenograft']
#
# Cluster 227
# ['analyses']
#
# Cluster 228
# ['first']
#
# Cluster 229
# ['strong']
#
# Cluster 230
# ['feature', 'measure', 'markov', 'hmm', 'hidden', 'building']
#
# Cluster 231
# ['mice', 'sirna', 'ir', 'h460r', 'mef', 'hnf1b', 'parental', 'sntb2', 'glut2']
#
# Cluster 232
# ['humans', 'modern', 'neanderthals']
#
# Cluster 233
# ['chain', 'id', 'vector', 'pdb', 'template']
#
# Cluster 234
# ['indicate', 'usually', 'reduced', 'close', 'tend', 'ifi6']
#
# Cluster 235
# ['associated', 'diseases', 'common', 'phenotypes', 'susceptibility']
#
# Cluster 236
# ['acid', 'amino', 'acids']
#
# Cluster 237
# ['1b', '1a', '2a', '2b', 'figs', '3a']
#
# Cluster 238
# ['e', 'g']
#
# Cluster 239
# ['furthermore', 'include', 'moreover', 'mainly', 'suggests', 'contribute', 'unknown', 'some', 'though', 'potentially', 'accumulation']
#
# Cluster 240
# ['instance']
#
# Cluster 241
# ['demonstrated', 'progression', 'immune', 'pathogenesis', 'ors', 'tumorigenesis', 'sjs', 'involvement', 'oncogenic']
#
# Cluster 242
# ['enriched', 'indicated', 'except', 'whose', 'hypermethylated']
#
# Cluster 243
# ['samples', 'normal', 'blood', 'plasma']
#
# Cluster 244
# ['peptide', 'etc', 'petrii', 'cysq', 'lpxd']
#
# Cluster 245
# ['region', 'within', 'chromosome', 'located', 'locus']
#
# Cluster 246
# ['world', 'past', 'areas', 'biobanks', 'countries', 'united']
#
# Cluster 247
# ['however', 'due', 'since', 'there', 'even', 'diversity', 'despite']
#
# Cluster 248
# ['species']
#
# Cluster 249
# ['size']
#
# Cluster 250
# ['system', 'service', 'authorization', 'source', 'taxonomy', 'language']
#
# Cluster 251
# ['tag', 'fragments', 'probes', 'cgi', 'amplified', 'primers', 'primer', 'peaks']
#
# Cluster 252
# ['linked', 'responsible', 'characterized', 'leads', 'thought', 'gut', 'act', 'selective', 'induce', 'controlling', 'implicated', 'regulators']
#
# Cluster 253
# ['direct', 'variety', 'editing']
#
# Cluster 254
# ['algorithm', 'tree', 'uses', 'implemented']
#
# Cluster 255
# ['factor', 'family']
#
# Cluster 256
# ['2000', 'mgiseq']
#
# Cluster 257
# ['defined', 'contains', 'represent', 'frequent', 'content', 'identity']
#
# Cluster 258
# ['t']
#
# Cluster 259
# ['clinical', 'characteristics', 'diagnostic']
#
# Cluster 260
# ['the']
#
# Cluster 261
# ['using', 'performed']
#
# Cluster 262
# ['recent', 'report', 'established', 'reports', 'more', 'progress', 'rapid']
#
# Cluster 263
# ['responses', 'emt', 'tm4sf5', 'activities', 'rage', 'regulating', 'transport', 'tmprss4', 'stress', 'enhanced', 'induction', 'induces', 'transduction', 'senescence']
#
# Cluster 264
# ['resulted', 'capacity', 'origin', 'indeed', 'earlier']
#
# Cluster 265
# ['synthesis', 'produce', 'transposition', 'rich']
#
# Cluster 266
# ['genome', 'whole']
#
# Cluster 267
# ['near', 'splice', 'overlapped', 'intronic', 'tsss', 'cpgis']
#
# Cluster 268
# ['excluded', 'male', 'males', 'females', 'oh', 'median', 'allelic', 'ct']
#
# Cluster 269
# ['fusion', 'errors', 'capture', 'quantification', 'sanger']
#
# Cluster 270
# ['see', 'summarized', 'listed']
#
# Cluster 271
# ['synonymous']
#
# Cluster 272
# ['alterations', 'heterogeneity', 'driver', 'clinically']
#
# Cluster 273
# ['variables', 'regression', 'area', 'tested', 'logistic', 'covariates', 'adjusted', 'additive']
#
# Cluster 274
# ['also', 'may', 'might', 'suggested', 'evidence', 'environmental']
#
# Cluster 275
# ['mutations', 'mutation', 'somatic']
#
# Cluster 276
# ['72', '120', 'temperature', 'cycles', 'medium', 'day']
#
# Cluster 277
# ['conserved', 'form', 'trna']
#
# Cluster 278
# ['average', 'less', 'least', 'times', '90', 'every', '99', 'interval', '93', '1c']
#
# Cluster 279
# ['28', '33', '35', '45', '37', '36', '48', '52', '65', '73']
#
# Cluster 280
# ['includes', 'modified', 'prior', 'details', 'scheme', 'optimization', 'rule', 'typically', 'typical', 'reliability']
#
# Cluster 281
# ['derived', 'host', 'events', 'bacteria']
#
# Cluster 282
# ['compounds', 'docking', 'ligand', 'ligands', 'e6']
#
# Cluster 283
# ['constructed', 'space', 'obtain', 'measures', 'composite', 'normalization', 'attributes', 'filter']
#
# Cluster 284
# ['thaliana', 'rapa']
#
# Cluster 285
# ['korean', 'kare', 'cohort', 'criteria']
#
# Cluster 286
# ['genomics', 'application', 'public', 'currently', 'resources', 'community', 'field', 'applications', 'biomedical']
#
# Cluster 287
# ['silico', 'existing', 'term', 'supports', 'entities', 'proper', 'entity', 'neural', 'ner']
#
# Cluster 288
# ['values', 'value', 'calculated', 'threshold']
#
# Cluster 289
# ['amount', 'rapidly', 'thousands', 'amounts', 'massive', 'parallel']
#
# Cluster 290
# ['presented', 'mesh', 'definition', 'mixed', 'generalized']
#
# Cluster 291
# ['phase', 'free', 'water']
#
# Cluster 292
# ['coefficient', 'coefficients', 'ratios', 'computed', 'absolute', 'sum']
#
# Cluster 293
# ['measurement', 'measuring', 'dpcr']
#
# Cluster 294
# ['interactions', 'interaction']
#
# Cluster 295
# ['growth', 'insulin', 'response', 'production', 'cox', 'infection', 'resistance', 'migration', 'inflammatory', 'secretion', 'overexpression', 'inflammation']
#
# Cluster 296
# ['performance', 'mdr']
#
# Cluster 297
# ['matrix', 'best', 'similarity', 'random', 'parameters', 'node', 'covariance', 'classifier', 'matrices']
#
# Cluster 298
# ['alignment', 'file', 'files', 'format', 'build', 'output']
#
# Cluster 299
# ['types']
#
# Cluster 300
# ['center', 'institute']
#
# Cluster 301
# ['type']
#
# Cluster 302
# ['this']
#
# Cluster 303
# ['drug']
#
# Cluster 304
# ['title']
#
# Cluster 305
# ['dimensional', 'representation', 'concepts', 'property', 'names', 'screen', 'artificial']
#
# Cluster 306
# ['successfully', 'sqtls']
#
# Cluster 307
# ['sensitivity', 'specificity']
#
# Cluster 308
# ['hps', 'putative', 'hypothetical']
#
# Cluster 309
# ['at', 'iii', 'marked', 'trf', 'tail']
#
# Cluster 310
# ['six', 'counts', 'divided', 'randomly']
#
# Cluster 311
# ['treated', 'decreased', 'serum', 'muscle', 'casz1', 'downregulated']
#
# Cluster 312
# ['disease', 'related']
#
# Cluster 313
# ['korea', 'university', 'national', 'seoul', 'dr', 'hospital']
#
# Cluster 314
# ['molecular', 'natural']
#
# Cluster 315
# ['structure', 'domain', 'structures', 'domains', 'secondary', 'homology', 'metal']
#
# Cluster 316
# ['pathway']
#
# Cluster 317
# ['sample']
#
# Cluster 318
# ['different']
#
# Cluster 319
# ['population', 'populations']
#
# Cluster 320
# ['analyzed']
#
# Cluster 321
# ['receptor', 'mutant', 'wild']
#
# Cluster 322
# ['0', 'p', 'ratio', '05', '01', 'height', '04', '001']
#
# Cluster 323
# ['lncrnas', 'nc886', 'targeting', 'post', 'trfs', 'aberrant', 'initiation']
#
# Cluster 324
# ['initial', 'achieved', 'check', 'recommended', 'options', 'applying', 'option', 'taking', 'sampling', 'experiment', 'fusionscan', 'briefly', 'achieve']
#
# Cluster 325
# ['tags', 'bar', 'left', 'percentage', 'normalized', 'intensity', 'gc', 'plotted', 'upper']
#
# Cluster 326
# ['selection', 'relationship']
#
# Cluster 327
# ['array', 'affymetrix', 'santa', '1000']
#
# Cluster 328
# ['we']
#
# Cluster 329
# ['yeast']
#
# Cluster 330
# ['r2', 'call', 'quantile', 'equilibrium', 'yorkshire', 'landrace', 'hardy', 'weinberg', 'counted']
#
# Cluster 331
# ['variant', 'cnv', 'cnvs']
#
# Cluster 332
# ['complex', 'ctcf', 'cohesin']
#
# Cluster 333
# ['general', 'extended', 'note', 'follow', 'observations', 'special', 'verified']
#
# Cluster 334
# ['increasing', 'uterine', 'metritis', 'microbiota']
#
# Cluster 335
# ['ethnic', 'koreans', 'replicated', 'pulse', 'pigs']
#
# Cluster 336
# ['particular', 'fact']
#
# Cluster 337
# ['human']
#
# Cluster 338
# ['shown']
#
# Cluster 339
# ['genes']
#
# Cluster 340
# ['in']
#
# Cluster 341
# ['weight', 'error', 'log', 'auc', 'curve', 'square', 'en']
#
# Cluster 342
# ['large', 'scale']
#
# Cluster 343
# ['part', 'epigenome', 'projects', 'broad', 'ihec']
#
# Cluster 344
# ['years']
#
# Cluster 345
# ['kim', 'lee', 'approved', 'board']
#
# Cluster 346
# ['records']
#
# Cluster 347
# ['good', 'basis']
#
# Cluster 348
# ['therefore', 'provide', 'useful', 'would', 'still', 'researchers', 'us']
#
# Cluster 349
# ['numbers', 'positions', 'allowed', 'intergenic', 'genic', 'boundaries']
#
# Cluster 350
# ['25', '23', '22', '24', '26']
#
# Cluster 351
# ['while', 'integration', 'lack', 'context', 'making', 'utilized', 'extensive', 'suitable', 'ways', 'facilitate', 'insight', 'systematic', 'propose', 'integrating']
#
# Cluster 352
# ['depending', 'abundant', 'mostly', 'occurred', 'lineage']
#
# Cluster 353
# ['replication']
#
# Cluster 354
# ['many', 'several']
#
# Cluster 355
# ['relative', 'on', 'hand', 'cai']
#
# Cluster 356
# ['series', 'event', 'initially', 'fission', 'numt', 'dnas']
#
# Cluster 357
# ['ucsc', 'browser']
#
# Cluster 358
# ['control', 'individuals', 'cases', 'controls', 'healthy']
#
# Cluster 359
# ['developing', 'heterogeneous', 'prognostic', 'outcomes', 'trials']
#
# Cluster 360
# ['showing', 'change', 'beta']
#
# Cluster 361
# ['a', 'b', 'c']
#
# Cluster 362
# ['discovery', 'screening', 'better', 'improve']
#
# Cluster 363
# ['finally', 'nodes', 'locations', 'clustered', 'diagram', 'blat']
#
# Cluster 364
# ['snp', 'markers', 'marker']
#
# Cluster 365
# ['called']
#
# Cluster 366
# ['genomic']
#
# Cluster 367
# ['diabetes', 'syndrome', 'hypertension']
#
# Cluster 368
# ['transcription', 'chromatin', 'histone', 'modifications', 'modification']
#
# Cluster 369
# ['specifically', 'affects', 'closely', 'neuronal', 'ros']
#
# Cluster 370
# ['generated', 'platform', 'library', 'raw']
#
# Cluster 371
# ['obtained']
#
# Cluster 372
# ['development', 'drugs', 'therapeutic']
#
# Cluster 373
# ['remaining', 'eight', 'representing', 'displayed', 'zero', 'taxa', 'distributions', 'distances', 'drawn']
#
# Cluster 374
# ['quantitative']
#
# Cluster 375
# ['method', 'methods']
#
# Cluster 376
# ['table', 'supplementary', 'tables']
#
# Cluster 377
# ['improved', 'reduce', 'assessment', 'external', 'link', 'tensor', 'avoid']
#
# Cluster 378
# ['could', 'whether']
#
# Cluster 379
# ['dominant', 'almost', 'increases']
#
# Cluster 380
# ['analysis']
#
# Cluster 381
# ['without']
#
# Cluster 382
# ['from', 'additionally', 'composition', 'gain', 'subset', 'other', 'categorized', 'connected']
#
# Cluster 383
# ['cluster', 'represented', 'assigned', 'box', 'ramachandran']
#
# Cluster 384
# ['cancer', 'tumor', 'tissues', 'tissue', 'breast', 'primary']
#
# Cluster 385
# ['most', 'kinds', 'during', 'newly', 'examples', 'fundamental', 'nevertheless', 'availability', 'toward', 'discussed', 'papers']
#
# Cluster 386
# ['genetic']
#
# Cluster 387
# ['graph', 'modeling', 'basic', 'done', 'local', 'optimized', 'hiscom', 'graphical']
#
# Cluster 388
# ['2017', '82', 'author', 'gi']
#
# Cluster 389
# ['impact', 'considering', 'relation', 'so', 'seems', 'determining', 'timing', 'extent']
#
# Cluster 390
# ['similar']
#
# Cluster 391
# ['association']
#
# Cluster 392
# ['viruses', 'eukaryotes', 'transfer', 'ncrnas', 'spatial', 'isoforms', 'lncrna']
#
# Cluster 393
# ['index', 'operating']
#
# Cluster 394
# ['abundance', 'when', 'variability', 'overlapping']
#
# Cluster 395
# ['based', 'available', 'user', 'visualization', 'input', 'designed']
#
# Cluster 396
# ['another', 'review', 'work', 'design', 'paper']
#
# Cluster 397
# ['evolutionary']
#
# Cluster 398
# ['organization', 'vitro', 'vivo', 'pathogenic', 'pathogen', 'infections']
#
# Cluster 399
# ['green', 'formed', 'transition', 'alpha', 'gram', '74', 'phosphate', 'unigenes']
#
# Cluster 400
# ['9', '12', '11', '13', '14']
#
# Cluster 401
# ['overall', 'highest', 'lowest']
#
# Cluster 402
# ['crocodylus', 'probably', 'karyotype', 'producing']
#
# Cluster 403
# ['studies']
#
# Cluster 404
# ['higher', 'lower', 'tg', 'fat', 'hdlc', 'cholesterol', 'hdl']
#
# Cluster 405
# ['similarly', 'seen', 'let', '196b']
#
# Cluster 406
# ['tools', 'developed', 'provides', 'bioinformatics', 'provided', 'text', 'access', 'users']
#
# Cluster 407
# ['51', '69', 'ranging', '98', '94', 'chr1', '91', 'accepted', 'ml', 'fraction', 'ranged', '400']
#
# Cluster 408
# ['donor']
#
# Cluster 409
# ['interesting', 'finding', 'able', 'tried']
#
# Cluster 410
# ['products', 'core', 'deg', 'transgenic', 'release', 'isolation', 'master']
#
# Cluster 411
# ['compared', 'obese']
#
# Cluster 412
# ['increased', 'or', 'glucose', 'fasting']
#
# Cluster 413
# ['various', 'relevant', 'literature', 'insights', 'providing']
#
# Cluster 414
# ['sequencing', 'depth', 'exome']
#
# Cluster 415
# ['n']
#
# Cluster 416
# ['metabolic', 'obesity', 'chronic', 'disorders']
#
# Cluster 417
# ['rate', 'positive', 'rates', 'difference', 'density']
#
# Cluster 418
# ['complete', 'comparative', 'arabidopsis']
#
# Cluster 419
# ['test', 'significance']
#
# Cluster 420
# ['set', 'sets']
#
# Cluster 421
# ['factors']
#
# Cluster 422
# ['ne']
#
# Cluster 423
# ['then', 'consists', 'each', 'probe', 'added', 'heatmap', 'hit', 'starting']
#
# Cluster 424
# ['quality', 'following', 'standard']
#
# Cluster 425
# ['according', 'inc', 'protocol', 'japan', 'city']
#
# Cluster 426
# ['medical', 'medicine', 'precision', 'management', 'reviewed', 'animal', 'fda', 'personalized', 'food', 'care']
#
# Cluster 427
# ['simulation']
#
# Cluster 428
# ['component']
#
# Cluster 429
# ['ontology']
#
# Cluster 430
# ['comparison']
#
# Cluster 431
# ['time']
#
# Cluster 432
# ['african', 'asia', 'generations']
#
# Cluster 433
# ['determined']
#
# Cluster 434
# ['order']
#
# Cluster 435
# ['genomes', 'plant']
#
# Cluster 436
# ['gwas', 'genomewide']
#
# Cluster 437
# ['open', 'an', 'generate', 'simple', 'pubannotation', 'named', 'grid', 'extraction', 'inception', 'interface', 'lapps', 'token', 'built', 'schema', 'automatically']
#
# Cluster 438
# ['range']
#
# Cluster 439
# ['imputation', 'summary', 'comparing', 'panels', 'positives', 'calls']
#
# Cluster 440
# ['risk', 'effect', 'effects']
#
# Cluster 441
# ['group']
#
# Cluster 442
# ['viral', 'via', 'bacterial', 'virus', 'enzymes']
#
# Cluster 443
# ['targets', 'inhibitors', 'hpv']
#
# Cluster 444
# ['patients', 'patient', 'status']
#
# Cluster 445
# ['revealed']
#
# Cluster 446
# ['signal', 'nuclear', 'enhancer', 'bound']
#
# Cluster 447
# ['r', 'package', 'run', 'default', 'suite', 'visualized']
#
# Cluster 448
# ['contrast']
#
# Cluster 449
# ['element', 'contain', 'repeats', 'retrotransposons', 'repeat', 'l1', 'ltr']
#
# Cluster 450
# ['residues', 'energy', 'residue', 'hydrogen', 'bonds', 'bond']
#
# Cluster 451
# ['methylation']
#
# Cluster 452
# ['short', 'longer', 'fragment', 'restriction', 'chromhmm']
#
# Cluster 453
# ['non']
#
# Cluster 454
# ['degs', 'versus', 'hdfs', 'dmso']
#
# Cluster 455
# ['it', 'thus']
#
# Cluster 456
# ['chosen', 'canonical', 'assumed', 'combinations', 'exact', 'abundances']
#
# Cluster 457
# ['conducted', 'resource']
#
# Cluster 458
# ['mirnas', 'mirna']
#
# Cluster 459
# ['found']
#
# Cluster 460
# ['function', 'like', 'molecules', 'enzyme']
#
# Cluster 461
# ['body']
#
# Cluster 462
# ['signals', 'interestingly', 'indicating']
#
# Cluster 463
# ['class', 'presence', 'trnas', 'subunit']
#
# Cluster 464
# ['features']

# %% [markdown]
# # Multidimensional Scaling

# %%
# calculate distribution
dist = 1-cosine_similarity(gniwv.vectors)

# initialize MDS
MDS()

# 
mds = MDS(n_components=2, dissimilarity = "precomputed", random_state=1)
pos = mds.fit_transform(dist)

xs, ys = pos[:,0], pos[:,1]

# %%
cluster_colors = {35: '#1b9e77', 36: '#d95f02', 37: '#7570b3', 38: '#e7298a', 39: '#66a61e'}

cluster_names = {35: 'Cluster105', 
                 36: 'Cluster106', 
                 37: 'Cluster107', 
                 38: 'Cluster108', 
                 39: 'Cluster109'
                }

# %%
# %matplotlib inline
import pandas as pd
clusters = kmeans_clustering.labels_.tolist()
df_all = pd.DataFrame(dict(x=xs, y=ys,title=gniwv.index2word, label=index))
condition = ( df_all['label'] >= 35 ) & ( df_all['label'] < 40 )
df = df_all[condition]
groups = df.groupby('label')
# Out:
#              x         y          title  label
# 78    0.687148  0.014221        regions     38
# 113  -0.001262 -0.675621      important     35
# 117   0.435938  0.559527             20     36
# 144   0.510738  0.483494   respectively     36
# 160   0.197629 -0.655070           role     35
# 176  -0.026305 -0.670899      potential     35
# 294   0.495976 -0.413356           lung     37
# 310  -0.029142 -0.652742     mechanisms     35
# 326   0.387735 -0.568085        cancers     37
# 340   0.587495 -0.144196        introns     38
# 382   0.097926 -0.626232      processes     35
# 419   0.062853 -0.648835      mechanism     35
# 453   0.091158 -0.630244          roles     35
# 464   0.478127 -0.026934         intron     38
# 497   0.084642 -0.579682      essential     35
# 560   0.129822 -0.586665           play     35
# 606  -0.408934  0.263143      collected     39
# 611   0.509752 -0.388991          liver     37
# 715   0.150455 -0.499772           lead     35
# 740   0.411617  0.493151  approximately     36
# 742   0.426326 -0.442280         tumors     37
# 746  -0.018509 -0.559453            key     35
# 919   0.017568 -0.546445       critical     35
# 1005  0.498567 -0.326660         kidney     37
# 1056  0.328440 -0.316345            atc     37
# 1158  0.229307 -0.544267          plays     35
# 1214  0.417987 -0.362516     colorectal     37
# 1303  0.427383 -0.276022       prostate     37
# 1304  0.463628 -0.236270      carcinoma     37
# 1449  0.405258 -0.317204          acute     37
# 1485  0.428042 -0.229269          colon     37
# 1504 -0.597103 -0.093578           tcga     39
# 1561  0.142254 -0.470099        crucial     35
# 1601  0.374160 -0.259235       leukemia     37
# 1608  0.139656 -0.327580          solid     37
# 1681  0.258541 -0.354714  developmental     37
# 1702  0.335872 -0.177939        thyroid     37
# 1807  0.404331 -0.295853          renal     37
# 1832  0.013655 -0.426242  physiological     35
# 2249  0.343399 -0.243181     pancreatic     37

# %%
fig, ax = plt.subplots(figsize=(17, 9)) # set size

ax.margins(0.05)

for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, 
                label=cluster_names[name],
            color=cluster_colors[name], 
            mec='none')
    ax.set_aspect('auto')
    ax.tick_params(\
        axis= 'x',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelbottom='off')
    ax.tick_params(\
        axis= 'y',         # changes apply to the y-axis
        which='both',      # both major and minor ticks are affected
        left='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelleft='off')

ax.legend(numpoints=1)

for i in range(len(df)):
    ax.text(df.iloc[i]['x'],
            df.iloc[i]['y'],
            df.iloc[i]['title'], size=12)  
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-1cd2fcbdc823> in <module>
# ----> 1 df['index']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'

# %% [markdown]
# # Find the cluster which include a specific word

# %%
def find_cluster_with_key(key):
    if not key in word_centroid_map.keys() :
        print("That word is not in keys")
    else :  
        cluster = word_centroid_map[key]
        print('\nCluster',cluster)
        words = []
        for k, c in word_centroid_map.items():
            if c == cluster :
                words.append(k)
        print(words)

# %%
print("================= Find Clustering ==================\n")
key = input("Enter a keyword: ")
find_cluster_with_key(key)
# Out:
# ================= Find Clustering ==================
#
# Enter a keyword: github
#
# Cluster 204
# ['page', 'uk', 'orcid', 'website', 'github', 'html', 'picard', 'gni']

# %%
abc = word_centroid_map['p53']
print(clus.index(abc))
print(keys.index('p53'))
# Out:
# 763
# 1514

# %%
len(gniwv.vectors)
# Out:
# 3788

# %%
len(index)
# Out:
# 3788
