# %% [markdown]
# # Abstract
#
#  Word2Vec을 활용하여 연도별로 GNI 코퍼스 내의 keywords들을 Clusturing한다.

# %%
# import nltk
import nltk
from nltk.corpus import *
from nltk import *

# libraries for word clustering
from gensim.models import Word2Vec
from sklearn.cluster import KMeans
import joblib

# import libraries for preprocessing
import re

# libraries for visualization
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.manifold import MDS
from sklearn.metrics.pairwise import cosine_similarity

import time

# %%
# using sentence tokenized gni corpus.
corpus_root = 'C:/Users/Maeg/nltk_data/Genomics-Informatics-Corpus-master/Genomics-Informatics-Corpus-master/GNI Corpus 1.0/sentence_tokenized'
GNIcorpus = PlaintextCorpusReader(corpus_root,'.*\.txt',encoding='utf-8')

# %% [markdown]
# # 전처리

# %%
# preprocessing each sentence
def gni_preprocessed_sents(gni_sents):
    
    # load stopwords and initialize preprocessed sentences list
    stops = set(stopwords.words("english"))
    wnl = nltk.WordNetLemmatizer()
    gni_pre_sents = []
    
    # remove non-letter words and stop words in each sentence
    for s in gni_sents :
        sent = []
        for w in s :
            if (re.match(r'[a-zA-Z0-9]+',w) !=  None) & (not w in stops) :
                sent.append(wnl.lemmatize(w.lower()))
        gni_pre_sents.append(sent)
    
    # return preprocessed sentences list
    return gni_pre_sents

# %%
# preprocessing GNI corpus
print("Start preprocessing... : G&I sentences")
gni_sents = gni_preprocessed_sents(GNIcorpus.sents())
print("End preprocessing: G&I sentences")
# Out:
# Start preprocessing... : G&I sentences
# End preprocessing: G&I sentences

# %% [markdown]
# # Modeling and Training Word2Vec

# %%
n_features = 300       # the number of Word2Vector Dimension
min_wordcount = 40     # Words which counts at least 20 times are available
n_workers = 4          # the number of parallel work
size_boundary = 10      # contextual window size
downsampling = 1e-3    # down sampling with frequent words

# Initialize and train Word2Vec model
print("Start Training ...")
model = Word2Vec(gni_sents,
                 workers = n_workers,
                 size = n_features,
                 min_count = min_wordcount,
                 window = size_boundary,
                 sample = downsampling)
print("End Training ")

# manage memory
model.init_sims(replace=True)

# save trained model
model.save("GNI_"+str(n_features)+"features_"+str(min_wordcount)+"minwords_"+str(size_boundary)+"window")
# Out:
# Start Training ...
# End Training

# %% [markdown]
# # Word Clustering
#
# Word2Vec으로 얻은 각 단어의 word vector를 이용하여 word cluster한다.

# %%
# clustering start time
start = time.time()
print("Start: Clustering")

# word vector of word2Vec model
gniwv = model.wv

# set the number of cluster
num_clusters = (int)(len(gniwv.vocab) / 5)

# Initialize a k-means object and use it to extract centroids(cluster)
kmeans_clustering = KMeans( n_clusters = num_clusters)
index = kmeans_clustering.fit_predict(gniwv.vectors)

end = time.time()
clustering_time = end - start
print("End  : Clustering")

# print Clustering information
print("\n============== Clustering Information ==============")
print("Clustering time:", clustering_time)
print("# of Word vectors:", len(gniwv.vocab))
print("# of Clusters:", num_clusters)
# Out:
# Start: Clustering
# End  : Clustering
#
# ============== Clustering Information ==============
# Clustering time: 38.91790795326233
# # of Word vectors: 2191
# # of Clusters: 438

# %%
# save the cluster models
joblib.dump(kmeans_clustering, 'GNI_words_cluster.pkl')
# Out:
# ['GNI_words_cluster.pkl']

# %%
# word - cluster number matching
word_centroid_map = dict(zip(gniwv.index2word, index))

# Print whole clutering results
for cluster in range(num_clusters) :
    print('\nCluster',cluster)
    words = []
    for k, c in word_centroid_map.items():
        if c == cluster :
            words.append(k)
    print(words)
# Out:
# Cluster 0
# ['still', 'microbial', 'limited', 'advance', 'epigenome', 'effort', 'metagenomic', 'technical', 'enabled']
#
# Cluster 1
# ['at', 'degree', 'similarly', 'circle', 'fish', 'black']
#
# Cluster 2
# ['altered', 'oncogenic']
#
# Cluster 3
# ['standard', 'initial', 'obtain', 'check', 'normalization', 'metric']
#
# Cluster 4
# ['obtained', 'quality', 'count', 'after', 'call', 'removed', 'filtered']
#
# Cluster 5
# ['population', 'asian', 'breed', 'cattle', 'hanwoo', 'holstein', 'african', 'pig', 'ancestry', 'east']
#
# Cluster 6
# ['occurred', 'cow', 'period', 'metritis', 'prevalent', 'half']
#
# Cluster 7
# ['faire', 'tss', 'upstream', 'island', 'transcribed', 'h3k4me3', 'h3k9', 'nucleosome', 'h3k4me1']
#
# Cluster 8
# ['20', '30', '50', '40', '60', '80', 'mm', '70', '65']
#
# Cluster 9
# ['approach', 'developed', 'knowledge', 'make', 'technique', 'computational', 'mining', 'efficient']
#
# Cluster 10
# ['increase', 'negative', 'reduced', 'decrease', 'specificity']
#
# Cluster 11
# ['search', 'query', 'blast']
#
# Cluster 12
# ['cell', 'mouse', 'liver', 'brain', 'carcinoma', 'death', 'heart', 'prostate', 'colon', 'lymphoma', 'renal', 'adenocarcinoma', 'pancreatic']
#
# Cluster 13
# ['proportion', 'substitution', 'explained', 'assumed']
#
# Cluster 14
# ['most', 'exist', 'newly', 'indeed', 'substantial', 'extent', 'accumulation']
#
# Cluster 15
# ['needed', 'developing', 'appropriate', 'trial', 'personalized', 'benefit', 'care', 'cma']
#
# Cluster 16
# ['e6', 'na', 'ns3', 'zikv', 'ofloxacin', 'lpxd', 'curcumin', 'antagonist', 'agonist', 'rif']
#
# Cluster 17
# ['tested']
#
# Cluster 18
# ['according', 'protocol', 'fisher', 'japan', 'city']
#
# Cluster 19
# ['directly', 'produce', 'editing', 'restriction', 'isolation']
#
# Cluster 20
# ['comparison', 'each', 'chosen', 'display', 'clustered', 'heatmap', 'displayed', 'drawn', 'visualized']
#
# Cluster 21
# ['whether', 'often', 'impact', 'explain', 'causal']
#
# Cluster 22
# ['regulated', 'pkd2', 'upregulated', 'pten', 'downregulated', 'mef']
#
# Cluster 23
# ['project', 'resource', 'published', 'center', 'institute', 'international', 'consortium']
#
# Cluster 24
# ['includes', 'mesh', 'portal', 'mysql', 'keywords', 'ictv']
#
# Cluster 25
# ['age', 'woman', 'crc', 'child', 'kd', 'gastritis', 'month', 'prevalence', 'incidence', 'sle', 'younger', 'ht']
#
# Cluster 26
# ['produced', 'phase', 'pre', 'preparation', 'prepared', 'bio', 'processed']
#
# Cluster 27
# ['relation', 'virulence', 'baumannii', 'acinetobactin', 'trans']
#
# Cluster 28
# ['mean', 'follows', 'confidence', 'log', 'maximum', 'deviation', 'square', 'minimum', 'quantile', 'q', 'mig']
#
# Cluster 29
# ['akt2', 'akt3']
#
# Cluster 30
# ['frequent']
#
# Cluster 31
# ['1', '2', '3', '4']
#
# Cluster 32
# ['mechanism', 'potential', 'epigenetic', 'key', 'critical', 'architecture']
#
# Cluster 33
# ['commonly', 'note', 'confirm', 'ass', 'little', 'clearly', 'unlike', 'situation']
#
# Cluster 34
# ['bacteria', 'organism', 're', 'eukaryote']
#
# Cluster 35
# ['genomic', 'amount']
#
# Cluster 36
# ['sva', 'contain', 'around', 'retrotransposons', 'l1', 'ltr', 'duplication', 'segment', 'inserted']
#
# Cluster 37
# ['complete', 'construction', 'workflow', 'ivag']
#
# Cluster 38
# ['simple', 'basic', 'pubannotation', 'taxonomy', 'interface', 'token', 'grid', 'framework', 'document', 'inception', 'created', 'layer', 'patent', 'lapp', 'object', 'schema', 'abstract', 'create', 'automatically', 'nlp']
#
# Cluster 39
# ['http', 'www', 'org', 'edu', 'com', 'ac']
#
# Cluster 40
# ['region', 'chromosome', 'intron', 'located', 'boundary', 'flanking', 'overlapped', 'intergenic', 'intronic', 'genic']
#
# Cluster 41
# ['expressed', 'differentially', 'hypermethylation']
#
# Cluster 42
# ['best', 'binary', 'blup', 'covariance']
#
# Cluster 43
# ['survival', 'hepatitis', 'adult', 'oral', 'vpa', 'adrs']
#
# Cluster 44
# ['insulin', 'lipid', 'strongly', 'correlated', 'lipoprotein']
#
# Cluster 45
# ['donor', 'isolated', 'cfdna', 'urine', 'peripheral']
#
# Cluster 46
# ['statistical', 'performance', 'accuracy', 'procedure', 'mdr', 'predictive']
#
# Cluster 47
# ['estimated', 'missing', 'r2', 'equilibrium', 'yorkshire', 'landrace', 'hardy', 'weinberg']
#
# Cluster 48
# ['tree', 'vector', 'us', 'markov', 'suffix']
#
# Cluster 49
# ['section', 'last', 'kim', 'reviewed', 'lee', 'follow', 'united']
#
# Cluster 50
# ['de', 'assembly', 'novo', 'rice']
#
# Cluster 51
# ['predicted', 'ion', '3d', 'backbone']
#
# Cluster 52
# ['this', 'therefore', 'understanding', 'help', 'understand', 'insight', 'relevant', 'providing']
#
# Cluster 53
# ['sequencing', 'technology', 'ng', 'next', 'generation', 'exome', 'throughput']
#
# Cluster 54
# ['28', '29', '33', '37', '36', '48', '52', '66']
#
# Cluster 55
# ['though', 'far', 'through', 'date', 'systematic', 'tried', 'fundamental', 'nevertheless', 'toward', 'completely']
#
# Cluster 56
# ['containing', 'presence', 'loop', 'terminal', 'superfamily', 'helix', 'transition', 'alpha', 'bound']
#
# Cluster 57
# ['investigated', 'gwass']
#
# Cluster 58
# ['file', 'alignment', 'map', 'format', 'input', 'output', 'build']
#
# Cluster 59
# ['transcription', 'chromatin', 'modification', 'histone']
#
# Cluster 60
# ['function', 'well', 'process', 'cellular', 'essential']
#
# Cluster 61
# ['inhibitor', 'cox', 'migration', 'inflammatory', 'involvement', 'vitro', 'rage', 'secretion', 'vivo', 'senescence']
#
# Cluster 62
# ['f']
#
# Cluster 63
# ['shown', '1b', '1a', '2a', '2b', '3a']
#
# Cluster 64
# ['interaction', 'biological', 'network']
#
# Cluster 65
# ['animal', 'world', 'past', 'country']
#
# Cluster 66
# ['read', 'length', 'base', 'mapped', 'raw', 'peak', 'bed', 'aligned']
#
# Cluster 67
# ['to', 'multiple', 'detect', 'reliable', 'detecting', 'analyzing']
#
# Cluster 68
# ['generated', 'generate', 'series', 'capture', 'digital', 'track']
#
# Cluster 69
# ['if', 'optimal', 'consider', 'hypothesis', 'define', 'generalized']
#
# Cluster 70
# ['n', 'x', 'd', 's', 'v', 'l', 'j', 'y', 'upper']
#
# Cluster 71
# ['include', 'soil', 'ability', 'nature', 'recognized', 'subsequently', 'during', 'accessibility', 'involving', 'discussed', 'capable', 'microorganism']
#
# Cluster 72
# ['independent', 'assumption', 'ethnicity', 'gwa']
#
# Cluster 73
# ['usually', 'chromosomal', 'mark', 'indicating', 'noncoding', 'spatial']
#
# Cluster 74
# ['except', '61', '67', '73', '89', '86', '92', '78', '88']
#
# Cluster 75
# ['clinical', 'biomarkers', 'heterogeneity', 'prognostic']
#
# Cluster 76
# ['another', 'design', 'focus', 'regarding', 'develop', 'link', 'regard', 'explore']
#
# Cluster 77
# ['side', 'amplified', 'sense', 'gc', '150', 'mer', 'barcodes']
#
# Cluster 78
# ['consists', 'composed', 'diagram', 'connected']
#
# Cluster 79
# ['positive', 'overall', 'false', 'true', 'absolute']
#
# Cluster 80
# ['distribution', 'ratio', 'fold', 'percentage', 'axis']
#
# Cluster 81
# ['tool', 'annotation', 'available', 'user', 'provides', 'integrated', 'visualization']
#
# Cluster 82
# ['they', 'frequently', 'occur', 'rearrangement']
#
# Cluster 83
# ['element', 'long', 'alu', 'event', 'te']
#
# Cluster 84
# ['mutation', 'somatic']
#
# Cluster 85
# ['end', 'fragment', 'primer', 'strand', 'cdna', 'stranded', 'dnase']
#
# Cluster 86
# ['gwas', 'dataset', 'all', 'kare', 'combined', 'genomewide', 'summary', 'catalog']
#
# Cluster 87
# ['detected', 'examined', 'confirmed', 'consistently']
#
# Cluster 88
# ['location', 'portion', 'carry']
#
# Cluster 89
# ['resulting', 'manner', 'stable', 'intermediate', 'exhibited', 'nine', 'light', 'endogenous']
#
# Cluster 90
# ['block', 'haplotype', 'ld', 'linkage', 'disequilibrium']
#
# Cluster 91
# ['there', 'focused', 'yet', 'importance', 'investigation', 'underlying', 'contribution', 'aimed', 'implication']
#
# Cluster 92
# ['cause', 'loss', 'disorder', 'leading', 'caused', 'suggesting']
#
# Cluster 93
# ['bmi', 'density', 'mass', 'grs', 'bmr', 'statistically', 'null', 'tt', 'gstm1']
#
# Cluster 94
# ['certain', 'depending', 'origin', 'clear', 'largely', 'selective', 'closely', 'inter', 'neuronal', 'hbv', 'morphology', 'severe', 'ifi6', 'defect']
#
# Cluster 95
# ['binding', 'active', 'bind', 'affinity', 'interact', 'substrate', 'hydrophobic', 'ama1', 'finger']
#
# Cluster 96
# ['entity', 'task', 'existing', 'named', 'utilized', 'neural', 'ner']
#
# Cluster 97
# ['database', 'annotated', 'ncbi', 'downloaded', 'accession', 'genbank']
#
# Cluster 98
# ['5', '10', '6', '8', '7']
#
# Cluster 99
# ['gi', 'release', '2013', 'website', 'orcid', 'released']
#
# Cluster 100
# ['evaluated', 'sensitivity', 'permutation', 'standardized', 'adjusted']
#
# Cluster 101
# ['diagnosis', 'prevention']
#
# Cluster 102
# ['a']
#
# Cluster 103
# ['two', 'three']
#
# Cluster 104
# ['following', 'run', 'plink', 'final', 'o', 'gb', 'default']
#
# Cluster 105
# ['history', 'outcome', 'gdm', 'facial', 'medication', 'conventional', 't2dm', 'adherence']
#
# Cluster 106
# ['showed', 'observed', 'strong', 'showing']
#
# Cluster 107
# ['variant', 'variation', 'rare']
#
# Cluster 108
# ['mirnas', 'regulation', 'mrna', 'revealed', 'mirna', 'transcriptional', 'trf', 'lncrnas', 'silencing', 'nc886', 'aberrant']
#
# Cluster 109
# ['pair', 'distance', 'least', 'pairwise', 'zero']
#
# Cluster 110
# ['relative', 'abundance']
#
# Cluster 111
# ['considering', 'additionally', 'reduction', 'rather', 'canonical', 'other', 'but', 'share', 'strength', 'examine', 'continuous', 'infer']
#
# Cluster 112
# ['usa', 'ca', 'real', 'right', 'inc', 'manufacturer', 'volume', 'instruction', 'qiagen', 'mixture', 'ma', 'san', 'plate', 'diego']
#
# Cluster 113
# ['research', 'genomics', 'issue', 'medical', 'medicine', 'life', 'scientific', 'science', 'informatics', 'genetics', 'management', 'fda']
#
# Cluster 114
# ['i']
#
# Cluster 115
# ['furthermore', 'mainly', 'able', 'suggests', 'signature', 'some', 'heterogeneous', 'possibility', 'driver', 'proven', 'phenomenon', 'potentially', 'serve', 'consequence']
#
# Cluster 116
# ['addition', 'contrast']
#
# Cluster 117
# ['repeat', 'motif', 'start', 'homologous', 'frame', 'reading', 'tandem', 'sine']
#
# Cluster 118
# ['similarity', 'cluster', 'node', 'represented', 'edge']
#
# Cluster 119
# ['human', 'specie', 'plant']
#
# Cluster 120
# ['sample']
#
# Cluster 121
# ['putative', 'zinc', 'interacting', 'duplex']
#
# Cluster 122
# ['physical', 'smoking', 'alcohol', 'consumption', 'intake']
#
# Cluster 123
# ['present', 'particular', 'fact', 'conclusion']
#
# Cluster 124
# ['involved', 'mediated', 'activation', 'metabolism', 'formation', 'act', 'regulate', 'targeting', 'emt', 'tm4sf5', 'regulator', 'stress', 'transport', 'regulating', 'biosynthesis', 'initiation', 'transduction']
#
# Cluster 125
# ['on', 'indicates', 'hand', 'tc', 'cai']
#
# Cluster 126
# ['respectively', 'ci', '64', '51', 'mg', '57', '75', '85', 'dl', '83', '71', '79']
#
# Cluster 127
# ['area', 'curve', 'auc', 'roc', 'operating', 'receiver']
#
# Cluster 128
# ['data', 'datasets']
#
# Cluster 129
# ['patient', 'normal', 'blood', 'plasma']
#
# Cluster 130
# ['title']
#
# Cluster 131
# ['expected', 'much', 'relatively']
#
# Cluster 132
# ['genetic', 'trait', 'phenotype', 'candidate']
#
# Cluster 133
# ['bp', 'state', '200', 'unit']
#
# Cluster 134
# ['regression', 'logistic', 'lasso', 'covariates', 'pca', 'additive']
#
# Cluster 135
# ['modern', 'neanderthal']
#
# Cluster 136
# ['instead', 'prior', 'scheme', 'setting', 'remove', 'optimization', 'internal', 'typically', 'fusionscan', 'character', 'typical', 'assessed', 'po', 'verified', 'reliability']
#
# Cluster 137
# ['0', 'p', '05', '01', 'height', '04', 'odds', 'fdr', '001', 'cutoff', 'counted']
#
# Cluster 138
# ['future', 'established', 'led', 'progress', 'promising']
#
# Cluster 139
# ['value', 'plot', 'calculated', 'coefficient', 'threshold']
#
# Cluster 140
# ['simulation', 'pharmacophore', 'screen', 'md']
#
# Cluster 141
# ['domain', 'conserved']
#
# Cluster 142
# ['example']
#
# Cluster 143
# ['korea', 'university', 'health', 'national', 'seoul', 'dr', 'hospital']
#
# Cluster 144
# ['duplicate', '2000', 'limit', 'qc', 'mgiseq']
#
# Cluster 145
# ['b', 'c', 't']
#
# Cluster 146
# ['current', 'conducted', 'precision', 'approved', 'written', 'biobanks', 'consent', 'improvement', 'laboratory', 'board', 'informed']
#
# Cluster 147
# ['disease', 'related', 'metabolic', 'hypertension']
#
# Cluster 148
# ['18', '17', '25', '23', '19', '22', '24', '26', '27']
#
# Cluster 149
# ['single', 'polymorphism', 'nucleotide']
#
# Cluster 150
# ['production', 'characterized', 'specifically', 'resulted', 'induce', 'enhanced', 'induction', 'transporter', 'implicated', 'cytokine', 'induces']
#
# Cluster 151
# ['al']
#
# Cluster 152
# ['pcr', 'reaction', 'amplification', 'assay', 'kit']
#
# Cluster 153
# ['localization', 'stability', 'folding']
#
# Cluster 154
# ['minor', 'maf', 'excluded', 'platelet']
#
# Cluster 155
# ['mutant', 'indicated', 'wild', 'mrp2', '1β', '74', 'glut2']
#
# Cluster 156
# ['specific', 'pattern']
#
# Cluster 157
# ['natural']
#
# Cluster 158
# ['array', 'affymetrix', 'santa', 'clara', '1000']
#
# Cluster 159
# ['composition']
#
# Cluster 160
# ['depth', 'illumina', 'coverage', 'paired']
#
# Cluster 161
# ['chain', 'id', 'template', 'pdb', 'kr']
#
# Cluster 162
# ['cancer', 'tumor', 'tissue', 'lung', 'breast', 'primary', 'kidney', 'colorectal', 'ovarian']
#
# Cluster 163
# ['90', 'interval', 'remaining', 'every', '99', 'fraction', 'ranging', '98', 'sd', 'chr1', '93', 'ranged', '400']
#
# Cluster 164
# ['may', 'it', 'could', 'important', 'thus', 'these', 'might']
#
# Cluster 165
# ['whereas', '35', '45', '34', '42', '41', '55', '53', '54', '58', '68', '59', '62']
#
# Cluster 166
# ['subsequent', 'extraction', 'deep', 'quantification', 'metagenome', 'initially', 'massive', 'parallel', 'availability', 'hybrid']
#
# Cluster 167
# ['translation', 'translational', 'post', 'transfer', 'thereby', 'ncrnas', 'isoforms', 'machinery', 'lncrna']
#
# Cluster 168
# ['indicate', 'when', 'dominant', 'almost', 'phenotypic', 'close', 'tend']
#
# Cluster 169
# ['significantly', 'tg', 'decreased', 'fat', 'hdlc', 'cholesterol', 'hdl']
#
# Cluster 170
# ['associated', 'common', 'susceptibility']
#
# Cluster 171
# ['first', 'original']
#
# Cluster 172
# ['using', 'performed']
#
# Cluster 173
# ['korean', 'subject', 'included', 'sex', 'heritability', 't1dm', 'fulminant', 'athlete']
#
# Cluster 174
# ['ago', 'let', '196b', 'phosphate', 'unigenes']
#
# Cluster 175
# ['code', 'along', 'seed', 'contained', 'master']
#
# Cluster 176
# ['snp', 'marker']
#
# Cluster 177
# ['thousand', 'hundred', 'ten']
#
# Cluster 178
# ['together', 'view', 'while', 'integration', 'compositional', 'integrating', 'integrative', 'proteomic']
#
# Cluster 179
# ['hpv', 'petrii', 'protease', 'namely', 'iron', 'surface', 'influenza', 'cysq', 'catalytic', 'coupled']
#
# Cluster 180
# ['type']
#
# Cluster 181
# ['total', 'average', '100', 'per']
#
# Cluster 182
# ['however', 'due', 'since', 'even', 'diversity']
#
# Cluster 183
# ['cpg', 'methylated', 'cgis']
#
# Cluster 184
# ['given', 'measure']
#
# Cluster 185
# ['differential', 'degs']
#
# Cluster 186
# ['general', 'detailed', 'shared', 'composite', 'overview', 'store']
#
# Cluster 187
# ['divided', 'randomly']
#
# Cluster 188
# ['new', 'application', 'review', 'researcher', 'work', 'strategy', 'field', 'community', 'biology', 'challenge']
#
# Cluster 189
# ['modified', 'added', 'rule', 'hmm', 'hidden', 'building', 'label', 'entry', 'descriptor', 'refined']
#
# Cluster 190
# ['seq', 'microarray', 'transcriptome', 'profiling']
#
# Cluster 191
# ['acid', 'amino']
#
# Cluster 192
# ['class']
#
# Cluster 193
# ['second', 'validation', 'cross', 'done', 'calculation', 'compare', 'definition', 'achieved', 'recommended', 'bayesian', 'robust', 'calculate', 'multivariate']
#
# Cluster 194
# ['of', 'milk', 'autosomal', 'nonsynonymous']
#
# Cluster 195
# ['from', 'subset', 'representative', 'seen', 'quite', 'taxon', 'figure']
#
# Cluster 196
# ['word', 'an', 'take', 'proper', 'vocabulary', 'inference']
#
# Cluster 197
# ['nimbolide', 'ir', 'muscle', 'h460r', 'parental', 'sntb2', 'rat']
#
# Cluster 198
# ['strain', 'coli', 'rapa', 'japonicum']
#
# Cluster 199
# ['encode', 'open', 'encyclopedia']
#
# Cluster 200
# ['employed', 'fast', 'solution', 'storage', 'iabio', 'dependency', 'visual', 'analytical', 'description', 'hiscom', 'external', 'image', 'interactive']
#
# Cluster 201
# ['step', 'platform', 'applied', 'pipeline', 'experiment', 'option', 'perform']
#
# Cluster 202
# ['stage', 'gastric', 'copd', 'bone']
#
# Cluster 203
# ['part', 'detail', 'ihec', 'cover', 'journal']
#
# Cluster 204
# ['tag', 'probe', 'bar', 'intensity', 'normalized', 'identity', 'root']
#
# Cluster 205
# ['form', 'double', 'transposition', 'gyrase', 'tail', 'cleavage']
#
# Cluster 206
# ['mostly', 'occurs', 'overlapping', 'overlap', 'direction', 'marked', 'cpgis', 'producing']
#
# Cluster 207
# ['variety', 'global', 'proteome']
#
# Cluster 208
# ['term', 'go', 'ontology']
#
# Cluster 209
# ['recent', 'report']
#
# Cluster 210
# ['structure', 'property', 'structural', 'hp', 'secondary', 'homology']
#
# Cluster 211
# ['exon', 'deletion', 'insertion']
#
# Cluster 212
# ['group']
#
# Cluster 213
# ['carried', 'modeling', 'dimensional', 'space', 'representation', 'optimized', 'subjected', 'graphical']
#
# Cluster 214
# ['our']
#
# Cluster 215
# ['use', 'problem', 'made', 'necessary', 'limitation', 'with', 'accurate', 'advantage', 'allows', 'overcome', 'practice']
#
# Cluster 216
# ['gene', 'enrichment']
#
# Cluster 217
# ['smaller', 'yield', 'exact', 'heterozygosity', 'heterozygous', 'allelic', 'concordance', 'outlier']
#
# Cluster 218
# ['response', 'growth', 'induced', 'anti', 'apoptosis', 'proliferation', 'suppressor', 'differentiation', 'invasion', 'abnormal', 'epithelial', 'oncogene', 'overexpression', 'tmprss4', 'inflammation']
#
# Cluster 219
# ['target']
#
# Cluster 220
# ['reported', 'previously']
#
# Cluster 221
# ['ne', 'people', 'recruited', 'south', 'american']
#
# Cluster 222
# ['others', 'cad', 'aspirin', 'ra']
#
# Cluster 223
# ['entire', 'variability', 'allowed', 'gap', 'starting', 'blat']
#
# Cluster 224
# ['including', 'condition', 'progression', 'immune', 'metastasis', 'developmental', 'agent']
#
# Cluster 225
# ['fig', 'table', 'supplementary']
#
# Cluster 226
# ['defined', 'k', 'represent', 'represents']
#
# Cluster 227
# ['one']
#
# Cluster 228
# ['literature', 'record', 'kimchi']
#
# Cluster 229
# ['fluid', 'distinguish', 'transplant', 'biopsy', 'pdx', 'dpcr']
#
# Cluster 230
# ['frequency', 'allele', 'hla']
#
# Cluster 231
# ['large', 'whole', 'scale']
#
# Cluster 232
# ['testing', 'admixture', 'dtc', 'consumer', 'company']
#
# Cluster 233
# ['significant', 'correlation', 'significance']
#
# Cluster 234
# ['described', 'presented']
#
# Cluster 235
# ['high', 'low']
#
# Cluster 236
# ['test', 'estimate', 'power']
#
# Cluster 237
# ['e', 'g']
#
# Cluster 238
# ['bmd', 'lpl', 'mets', 'klf5', 'lifestyle', 'lef1']
#
# Cluster 239
# ['among']
#
# Cluster 240
# ['library', 'chip', 'resolution', 'hybridization']
#
# Cluster 241
# ['experimental', 'widely', 'multi', 'here', 'analyze', 'purpose', 'interpretation', 'goal', 'aim', 'powerful', 'easy', 'omics', 'traditional']
#
# Cluster 242
# ['study', 'previous']
#
# Cluster 243
# ['consistent', 'metastatic', 'pc', 'penguin', 'cnas', 'western', 'xenograft', 'hnf1b', 'tp53']
#
# Cluster 244
# ['number', 'small', 'copy', 'across']
#
# Cluster 245
# ['increased', 'or', 'concentration', 'glucose', 'pressure', 'serum', 'fasting']
#
# Cluster 246
# ['m']
#
# Cluster 247
# ['codon', 'synonymous', 'usage']
#
# Cluster 248
# ['software', 'r', 'version', 'package', 'implemented', 'suite']
#
# Cluster 249
# ['expression', 'profile']
#
# Cluster 250
# ['promoter', 'signal', 'ctcf', 'peg3', 'enhancer', 'cohesin']
#
# Cluster 251
# ['panel', 'genotyping', 'imputation', 'hapmap', 'genotyped', 'snvs']
#
# Cluster 252
# ['unique', 'core', 'etc', 'encoded', 'involves', 'conservation', 'transposon', 'conversion', 'rich']
#
# Cluster 253
# ['family', 'activity', 'like', 'receptor', 'member', 'kinase', 'membrane', 'antigen', 'p53', 'channel']
#
# Cluster 254
# ['four', 'corresponding', 'six', 'left', 'eight', 'median', 'plotted', 'versus', 'leaf', 'oligonucleotides', '1c']
#
# Cluster 255
# ['diabetes', 'syndrome', 'obesity', 'chronic', 'poor', 'cardiovascular', 'symptom', 'coronary']
#
# Cluster 256
# ['crocodylus', 'crocodilian', 'probably', 'karyotype', 'earlier']
#
# Cluster 257
# ['energy', 'gram']
#
# Cluster 258
# ['difference', 'similar', 'subpopulation']
#
# Cluster 259
# ['comparative', 'thaliana', 'successfully', 'arabidopsis', 'sqtls']
#
# Cluster 260
# ['free', 'water', 'tank']
#
# Cluster 261
# ['different']
#
# Cluster 262
# ['primate', 'eukaryotic', 'throughout', 'transposable', 'numt']
#
# Cluster 263
# ['see', 'summarized', 'listed']
#
# Cluster 264
# ['proposed']
#
# Cluster 265
# ['for']
#
# Cluster 266
# ['list', 'deg']
#
# Cluster 267
# ['rt', 'iii', 'transgenic']
#
# Cluster 268
# ['9', '15', '16', '12', '11', '13', '14']
#
# Cluster 269
# ['model', 'prediction']
#
# Cluster 270
# ['sequence', 'short', 'longer', 'chromhmm']
#
# Cluster 271
# ['contains', 'content', 'genus', 'occurrence', 'representing', 'respect', 'symbol', 'match']
#
# Cluster 272
# ['complex']
#
# Cluster 273
# ['moreover', 'generally', 'gain', 'majority', 'seems', 'determining', 'timing', 'occurring']
#
# Cluster 274
# ['component']
#
# Cluster 275
# ['provided', 'public', 'currently', 'biomedical', 'publication', 'repository', 'pubmed', 'guideline']
#
# Cluster 276
# ['rna']
#
# Cluster 277
# ['the']
#
# Cluster 278
# ['wide']
#
# Cluster 279
# ['system']
#
# Cluster 280
# ['ethnic', 'validated', 'asia', 'replicated', 'parent', 'trend', 'pulse']
#
# Cluster 281
# ['better', 'improve', 'investigate', 'evaluate', 'validate', 'predicting']
#
# Cluster 282
# ['peptide']
#
# Cluster 283
# ['non', 'coding', 'transcript']
#
# Cluster 284
# ['sirna', 'antibody', 'casz1']
#
# Cluster 285
# ['in']
#
# Cluster 286
# ['site', 'recombination', 'near', 'splice']
#
# Cluster 287
# ['text', 'bioinformatics', 'service', 'source', 'processing', 'access', 'corpus', 'language', 'authorization', 'bionlp']
#
# Cluster 288
# ['individual', 'status', 'gender']
#
# Cluster 289
# ['collected', 'tcga']
#
# Cluster 290
# ['red', 'color', 'beta', 'blue', 'assigned', 'green', 'box', 'dot']
#
# Cluster 291
# ['line']
#
# Cluster 292
# ['analysis']
#
# Cluster 293
# ['ranked']
#
# Cluster 294
# ['dna']
#
# Cluster 295
# ['extracted', 'requires', 'collection', 'stored', 'broad', 'commercial']
#
# Cluster 296
# ['regulatory', 'alternative', 'splicing', 'hotair']
#
# Cluster 297
# ['seven', 'consisting', 'appeared', '63', 'km']
#
# Cluster 298
# ['diagnostic', 'despite', 'aml', 'already', 'clinically']
#
# Cluster 299
# ['et']
#
# Cluster 300
# ['alteration', 'evolution', 'organization', 'instability', 'epigenomic']
#
# Cluster 301
# ['signaling', 'cycle', 'dependent', 'nf', 'kdo', 'ifn', 'inhibition', 'activated', 'br', 'tnf', 'stimulation']
#
# Cluster 302
# ['size', 'larger']
#
# Cluster 303
# ['identify', 'provide', 'discovery', 'identification', 'possible', 'useful', 'find', 'identifying', 'interest', 'discover']
#
# Cluster 304
# ['pathway']
#
# Cluster 305
# ['set']
#
# Cluster 306
# ['japanese', 'european', 'chinese']
#
# Cluster 307
# ['kegg', 'kyoto']
#
# Cluster 308
# ['algorithm', 'finally', 'constructed', 'then', 'filtering', 'fixed', 'training', 'filter', 'applying', 'partition', 'gatk']
#
# Cluster 309
# ['designed', 'memory', 'full', 'window', 'built', 'converted', 'script', 'bam', 'java']
#
# Cluster 310
# ['affect', 'likely', 'influence', 'affected', 'hearing', 'affecting']
#
# Cluster 311
# ['although', 'finding', 'evidence', 'suggest']
#
# Cluster 312
# ['matched']
#
# Cluster 313
# ['required', 'especially', 'direct', 'become', 'microbiome', 'complexity', 'particularly', 'numerous', 'aspect', 'question', 'characterization', 'discus', 'opportunity']
#
# Cluster 314
# ['considered']
#
# Cluster 315
# ['highly']
#
# Cluster 316
# ['locus', 'mtdna', 'polymorphic']
#
# Cluster 317
# ['atc', 'sensitive', 'sjs', 'chromothripsis', 'acute', 'resistant', 'leukemia', 'solid', 'organ', 'thyroid', 'circulating']
#
# Cluster 318
# ['food', 'central', 'introduction']
#
# Cluster 319
# ['virus', 'viral', 'host', 'bacterial']
#
# Cluster 320
# ['role', 'play', 'suggested', 'lead', 'contribute', 'pathogenesis', 'tumorigenesis', 'crucial']
#
# Cluster 321
# ['nc', 'healthy', 'young', 'diagnosed', 'mortality']
#
# Cluster 322
# ['identified']
#
# Cluster 323
# ['environment', 'introduced', 'comprehensive', 'metagenomics', 'advanced', 'making', 'allow', 'extensive', 'suitable', 'enables', 'facilitate', 'principle', 'propose', 'attempt', 'methodology', 'describe', 'adopted', 'scientist', 'enable', 'perspective']
#
# Cluster 324
# ['category']
#
# Cluster 325
# ['selected', 'top']
#
# Cluster 326
# ['detection', 'targeted', 'cost', 'wes', 'oncochase']
#
# Cluster 327
# ['many', 'several', 'novel', 'recently', 'discovered']
#
# Cluster 328
# ['analyzed']
#
# Cluster 329
# ['selection', 'meta', 'estimation', 'fst', 'estimating']
#
# Cluster 330
# ['article', 'paper']
#
# Cluster 331
# ['characteristic']
#
# Cluster 332
# ['module', 'string', 'hypothetical']
#
# Cluster 333
# ['called', 'by', 'local', 'construct', 'correct', 'taxonomic', 'consensus', 'msdna']
#
# Cluster 334
# ['third', 'both', 'no', 'flow', 'repeated', 'separate', 'accepted', 'consisted', 'remained']
#
# Cluster 335
# ['position']
#
# Cluster 336
# ['variable', 'variance', 'linear', 'statistic', 'likelihood', 'weighted', 'en', 'slr']
#
# Cluster 337
# ['000', 'million', 'approximately', '500']
#
# Cluster 338
# ['reference', 'mapping', 'calling']
#
# Cluster 339
# ['further', 'taken', 'supported', 'hence', 'neuropeptides', 'upon', 'mode', 'towards']
#
# Cluster 340
# ['known', 'major', 'linked', 'responsible', 'causing', 'thought', 'gut', 'pathogenic', 'functionally']
#
# Cluster 341
# ['error', 'comparing', 'background', 'sampling', 'achieve']
#
# Cluster 342
# ['main', 'good', 'basis', 'evaluation', 'improved', 'assessment', 'predictor', 'decision']
#
# Cluster 343
# ['biomarker', 'deps']
#
# Cluster 344
# ['residue', 'bond', 'hydrogen', 'rpob', 'formed', 'kir6']
#
# Cluster 345
# ['measurement', 'correction', 'removing', 'rank', 'principal', 'classifier', 'computed', 'mixed', 'sum']
#
# Cluster 346
# ['also']
#
# Cluster 347
# ['various', 'diverse']
#
# Cluster 348
# ['mutated']
#
# Cluster 349
# ['nuclear', 'co', 'downstream', 'precursor', 'subunit', 'encoding', 'hp1', 'encodes', 'phosphorylation', 'mature', 'nucleus']
#
# Cluster 350
# ['program', 'web', 'server', 'page']
#
# Cluster 351
# ['enzyme', 'via', 'synthesis', 'repair', 'damage']
#
# Cluster 352
# ['extended', 'account', 'hard', 'special', 'briefly', 'actual']
#
# Cluster 353
# ['distributed', 'largest', 'divergence', 'ancestral']
#
# Cluster 354
# ['combination']
#
# Cluster 355
# ['drug']
#
# Cluster 356
# ['genome']
#
# Cluster 357
# ['95', 'h', 'min', '2017', 'day', '72', '82', '120', 'temperature', '94', '91', 'ml']
#
# Cluster 358
# ['score', 'matrix', 'parameter', 'weight', 'random', 'z', 'probability']
#
# Cluster 359
# ['highest', 'lowest', 'mol', 'kcal']
#
# Cluster 360
# ['author']
#
# Cluster 361
# ['without', 'determine', 'because', 'difficult', 'cannot', 'enough', 'sufficient']
#
# Cluster 362
# ['cohort', 'participant', 'ansan', 't2d', '842']
#
# Cluster 363
# ['quantitative', 'bias', 'measuring']
#
# Cluster 364
# ['method']
#
# Cluster 365
# ['factor']
#
# Cluster 366
# ['hit', 'determined', 'angle', 'atom', 'ramachandran']
#
# Cluster 367
# ['time']
#
# Cluster 368
# ['show']
#
# Cluster 369
# ['order']
#
# Cluster 370
# ['so', 'spectrum', 'extract', 'capacity', 'adaptation', 'consequently', 'regarded']
#
# Cluster 371
# ['gov', 'nih', 'retrieved', 'nlm', 'online', 'uk', 'uniprot']
#
# Cluster 372
# ['control']
#
# Cluster 373
# ['cgi']
#
# Cluster 374
# ['we']
#
# Cluster 375
# ['kind', 'context', 'mentioned', 'helpful', 'besides', 'demonstrate', 'offer', 'fully', 'explored']
#
# Cluster 376
# ['treated', 'hdfs', 'dmso']
#
# Cluster 377
# ['culture', 'medium']
#
# Cluster 378
# ['based', 'support', 'classification', 'way', 'concept', 'graph', 'machine', 'learning', 'semantic', 'attribute']
#
# Cluster 379
# ['replication']
#
# Cluster 380
# ['indels']
#
# Cluster 381
# ['mitochondrial']
#
# Cluster 382
# ['browser', 'ucsc']
#
# Cluster 383
# ['ii', 'stem']
#
# Cluster 384
# ['environmental', 'studied', 'unknown', 'action', 'physiological', 'controlling', 'ro', 'understood']
#
# Cluster 385
# ['lineage', 'abundant', 'subfamily', 'mammalian', 'mammal']
#
# Cluster 386
# ['mir', '21', '3p']
#
# Cluster 387
# ['index']
#
# Cluster 388
# ['effective', 'decade', 'rapidly', 'more', 'rapid', 'successful']
#
# Cluster 389
# ['trna']
#
# Cluster 390
# ['point', 'name', 'sub', 'phylogenetic', 'contiguous', 'maximal']
#
# Cluster 391
# ['screening']
#
# Cluster 392
# ['genotype', 'five', 'criterion', 'imputed']
#
# Cluster 393
# ['male', 'female', 'men', '69', 'oh']
#
# Cluster 394
# ['rate']
#
# Cluster 395
# ['found']
#
# Cluster 396
# ['chemical', 'dynamic', 'recognition', 'ape1']
#
# Cluster 397
# ['range']
#
# Cluster 398
# ['development', 'treatment', 'early', 'therapy', 'therapeutic', 'prognosis']
#
# Cluster 399
# ['evolutionary']
#
# Cluster 400
# ['31', '32', '38', '39', '46', 'il', '43', '56', '44', '47', '49']
#
# Cluster 401
# ['demonstrated', 'increasing', 'uterine', 'remains', 'microbiota']
#
# Cluster 402
# ['additional', 'easily', 'must', 'combining', 'require', 'popular', 'get', 'taking', 'material', 'speed', 'apply', 'select', 'combine', 'meaningful', 'avoid', 'expect', 'quantity']
#
# Cluster 403
# ['classified', 'distinct']
#
# Cluster 404
# ['information']
#
# Cluster 405
# ['methylation']
#
# Cluster 406
# ['effect', 'risk']
#
# Cluster 407
# ['leu', 'ala', 'phe', 'tyr', 'val']
#
# Cluster 408
# ['compared', 'obese']
#
# Cluster 409
# ['functional', 'relationship']
#
# Cluster 410
# ['derived']
#
# Cluster 411
# ['association']
#
# Cluster 412
# ['would', 'need', 'u', 'interesting', 'lack', 'give', 'reduce', 'reason', 'great']
#
# Cluster 413
# ['change']
#
# Cluster 414
# ['year']
#
# Cluster 415
# ['result']
#
# Cluster 416
# ['clustering', 'hierarchical']
#
# Cluster 417
# ['higher', 'le', 'lower', 'greater']
#
# Cluster 418
# ['within', 'kb', 'utr']
#
# Cluster 419
# ['er', 'docked', 'conformation', 'phosphoglucosamine', 'mutase']
#
# Cluster 420
# ['efficiency']
#
# Cluster 421
# ['observation', 'interestingly', 'exhibit', 'imprinted']
#
# Cluster 422
# ['measured', 'ct']
#
# Cluster 423
# ['used']
#
# Cluster 424
# ['molecular', 'ligand', 'compound', 'docking']
#
# Cluster 425
# ['protein', 'molecule', 'metal']
#
# Cluster 426
# ['predict', 'silico', 'theory', 'tensor', 'artificial']
#
# Cluster 427
# ['case']
#
# Cluster 428
# ['either', 'enriched', 'whose', 'hypermethylated']
#
# Cluster 429
# ['level', 'body', '27a', 'g64']
#
# Cluster 430
# ['fusion', 'sequenced', 'yeast', 'rrna', 'sanger', 'fission', 'clone']
#
# Cluster 431
# ['instance']
#
# Cluster 432
# ['infection', 'resistance', 'pathogen']
#
# Cluster 433
# ['polymerase', 'product', 'reverse']
#
# Cluster 434
# ['cnv', 'cnvs']
#
# Cluster 435
# ['feature']
#
# Cluster 436
# ['categorized']
#
# Cluster 437
# ['followed', 'gel', 'separated', '96', 'buffer', 'extension', 'electrophoresis', 'mix']

# %% [markdown]
# # Multidimensional Scaling

# %%
# calculate distribution
dist = 1-cosine_similarity(gniwv.vectors)

# initialize MDS
MDS()

# scaling multidimensions
mds = MDS(n_components=2, dissimilarity = "precomputed", random_state=1)
pos = mds.fit_transform(dist)

xs, ys = pos[:,0], pos[:,1]

# %% [markdown]
# # Visualization of Word vectors

# %%
# set colors and names of clusters
cluster_colors = {35: '#1b9e77', 36: '#d95f02', 37: '#7570b3', 38: '#e7298a', 39: '#66a61e'}
cluster_names = {35: 'Cluster35', 
                 36: 'Cluster36', 
                 37: 'Cluster37', 
                 38: 'Cluster38', 
                 39: 'Cluster39'
                }

# %%
# %matplotlib inline

# Create (x-position(2D), y-position(2D), word, cluster number) table
df_all = pd.DataFrame(dict(x=xs, y=ys,word=gniwv.index2word, label=index))

# Show only five Clusters, 35, 36, 37, 38, 39
condition = ( df_all['label'] >= 35 ) & ( df_all['label'] < 40 )
df = df_all[condition]

# grouping with cluster number
groups = df.groupby('label')
df

# %%
fig, ax = plt.subplots(figsize=(17, 9)) # set size

ax.margins(0.05)

for cluseter_n, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, 
                label=cluster_names[cluseter_n],
            color=cluster_colors[cluseter_n], 
            mec='none')
    ax.set_aspect('auto')
    ax.tick_params(\
        axis= 'x',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelbottom='off')
    ax.tick_params(\
        axis= 'y',         # changes apply to the y-axis
        which='both',      # both major and minor ticks are affected
        left='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelleft='off')

ax.legend(numpoints=1)

for i in range(len(df)):
    ax.text(df.iloc[i]['x'],
            df.iloc[i]['y'],
            df.iloc[i]['word'], size=12)  
plt.show()

# %% [markdown]
# # Find the cluster which include a specific word

# %%
# find cluster result with specipic keyword
def find_cluster_with_key(key):
    # if there is not key in vocab, do nothing
    if not key in word_centroid_map.keys() :
        print("That word is not in keys")
    # if there is key in vocab, print cluster result
    else :  
        cluster = word_centroid_map[key]
        print('\nCluster',cluster)
        words = []
        for k, c in word_centroid_map.items():
            if c == cluster :
                words.append(k)
        print(words)

# %%
key = input("============= Find Clustering ==============\nEnter a keyword: ")
find_cluster_with_key(key)
