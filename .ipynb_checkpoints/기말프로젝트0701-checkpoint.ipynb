# %% [markdown]
# # Named-E
#
# GNI 코퍼스로 부터 약어와 특수용어들을 가져온다.

# %%
import nltk
from nltk.corpus import *
from nltk import *
from nltk import RegexpTokenizer

# using sentence tokenized corpus
corpus_root = 'C:/Users/Maeg/nltk_data/Genomics-Informatics-Corpus-master/Genomics-Informatics-Corpus-master/GNI Corpus 1.0/sentence_tokenized'
GNIcorpus = PlaintextCorpusReader(corpus_root,'.*\.txt',encoding='utf-8')
raws = GNIcorpus.raw()

# %% [markdown]
# 1. Tokenization: 약어들과 일반적인 단어, 수치들이 나오도록 tokenziation한다.

# %%
pattern = r''' (?x)
          \$?\d+(?:\.\d+)?%?      # digits, percentags, and $
        | [a-z]+[A-Z]{2,}            # small letters + large letters
        | [A-Za-z]+[0-9]*         # letters + digit abb
        | [A-Z]{2,}[a-z]+
        | [A-Z]{2,}               # Large scale abb
        | (?=[A-Z]\.)+            # abb with dots. e.g.  U.S.A
        | [A-Za-z]+(?:-\w+)*            # general token with hyphens
        | (?![\]\[.,;\"\'?\(\):-_`&]) # do not capture separator
        |
'''
tokenizer = RegexpTokenizer(pattern)
words = tokenizer.tokenize(raws)
Result = [w for w in words if (w != '')]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-86-fe9ee1bf6dbc> in <module>
#      11 '''
#      12 tokenizer = RegexpTokenizer(pattern)
# ---> 13 words = tokenizer.tokenize(raws)
#      14 Result = [w for w in words if (w != '')]
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\regexp.py in tokenize(self, text)
#     124
#     125     def tokenize(self, text):
# --> 126         self._check_regexp()
#     127         # If our regexp matches gaps, use re.split:
#     128         if self._gaps:
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\regexp.py in _check_regexp(self)
#     121     def _check_regexp(self):
#     122         if self._regexp is None:
# --> 123             self._regexp = re.compile(self._pattern, self._flags)
#     124
#     125     def tokenize(self, text):
#
# ~\Anaconda3\lib\re.py in compile(pattern, flags)
#     231 def compile(pattern, flags=0):
#     232     "Compile a regular expression pattern, returning a pattern object."
# --> 233     return _compile(pattern, flags)
#     234
#     235 def purge():
#
# ~\Anaconda3\lib\re.py in _compile(pattern, flags)
#     299     if not sre_compile.isstring(pattern):
#     300         raise TypeError("first argument must be string or compiled pattern")
# --> 301     p = sre_compile.compile(pattern, flags)
#     302     if not (flags & DEBUG):
#     303         if len(_cache) >= _MAXCACHE:
#
# ~\Anaconda3\lib\sre_compile.py in compile(p, flags)
#     560     if isstring(p):
#     561         pattern = p
# --> 562         p = sre_parse.parse(p, flags)
#     563     else:
#     564         pattern = None
#
# ~\Anaconda3\lib\sre_parse.py in parse(str, flags, pattern)
#     867     if source.next is not None:
#     868         assert source.next == ")"
# --> 869         raise source.error("unbalanced parenthesis")
#     870
#     871     if flags & SRE_FLAG_DEBUG:
#
# error: unbalanced parenthesis at position 501 (line 10, column 34)

# %%
Result
# Out:
# ['.com']

# %%
'mFOLD' in words
# Out:
# False

# %% [markdown]
# 2. 전처리: 유전자코드 제거

# %%
re_genecode = r'[AGCT]{3,}'
Result = [w for w in words if (not re.match(re_genecode, w)) & (w != '')]
sorted(Result, reverse=True)
# Out:
# ['𝜖',
#  '𝜖',
#  '𝛽',
#  '𝛽',
#  '𝛽',
#  '𝛽',
#  '𝑦',
#  '𝑦',
#  '𝑣',
#  '𝑡',
#  '𝑠',
#  '𝑠',
#  '𝑟',
#  '𝑟',
#  '𝑟',
#  '𝑟',
#  '𝑜',
#  '𝑜',
#  '𝑜',
#  '𝑜',
#  '𝑜',
#  '𝑛',
#  '𝑛',
#  '𝑛',
#  '𝑙',
#  '𝑙',
#  '𝑙',
#  '𝑙',
#  '𝑙',
#  '𝑙',
#  '𝑗',
#  '𝑗',
#  '𝑗',
#  '𝑖',
#  '𝑖',
#  '𝑖',
#  '𝑖',
#  '𝑖',
#  '𝑖',
#  '𝑖',
#  '𝑖',
#  '𝑖',
#  '𝑖',
#  '𝑖',
#  '𝑖',
#  '𝑖',
#  '𝑖',
#  '𝑔',
#  '𝑔',
#  '𝑓',
#  '𝑓',
#  '𝑓',
#  '𝑓',
#  '𝑓',
#  '𝑑',
#  '𝑑',
#  '𝑐',
#  '𝑐',
#  '𝑐',
#  '𝑏',
#  '𝑎',
#  '𝑎',
#  '𝑎',
#  '𝑍',
#  '𝑍',
#  '𝑋',
#  '𝑋',
#  '𝑋',
#  '𝑋',
#  '𝑅',
#  '𝑅',
#  '𝑅',
#  '𝐼',
#  '𝐼',
#  '𝐻',
#  '𝐻',
#  '𝐸',
#  '𝐶',
#  '𝐶',
#  '𝐵',
#  '𝐵',
#  '𝐴',
#  '𝐴',
#  '𝐴',
#  'ﬁlters',
#  'Å2',
#  'Å2',
#  'ΩXn',
#  'ΩXn',
#  'ΩXn',
#  'ΩXn',
#  'ΩXn',
#  'ΩX',
#  'Ω',
#  'Ω',
#  'ℎ',
#  'ℎ',
#  'ℎ',
#  'ℎ',
#  'ℎ',
#  'ℎ',
#  'ϕDNA',
#  'ωψn',
#  'ωψk',
#  'ωψ2',
#  'ωψ1',
#  'ωφn',
#  'ωφk',
#  'ωφ2',
#  'ωφ1',
#  'ω',
#  'ω',
#  'ψ55',
#  'ψ2',
#  'ψ2',
#  'ψ2',
#  'ψ2',
#  'ψ2',
#  'ψ1',
#  'ψ1',
#  'ψ1',
#  'ψ1',
#  'ψ1',
#  'ψ',
#  'ψ',
#  'ψ',
#  'ψ',
#  'ψ',
#  'ψ',
#  'ψ',
#  'χjk',
#  'χjk',
#  'χj',
#  'χj',
#  'χj',
#  'χ2-test',
#  'χ2',
#  'χ2',
#  'χ2',
#  'χ2',
#  'χ2',
#  'χ2',
#  'χ2',
#  'χ2',
#  'φ2',
#  'φ2',
#  'φ2',
#  'φ2',
#  'φ2',
#  'φ1',
#  'φ1',
#  'φ1',
#  'φ1',
#  'φ1',
#  'φ',
#  'φ',
#  'φ',
#  'φ',
#  'φ',
#  'φ',
#  'τT',
#  'τP',
#  'τ',
#  'τ',
#  'τ',
#  'τ',
#  'τ',
#  'τ',
#  'τ',
#  'τ',
#  'τ',
#  'τ',
#  'τ',
#  'τ',
#  'σσ2p',
#  'σij',
#  'σi2X1',
#  'σi2',
#  'σi2',
#  'σi2',
#  'σi2',
#  'σi',
#  'σi',
#  'σi',
#  'σi',
#  'σW',
#  'σW',
#  'σW',
#  'σW',
#  'σ2p',
#  'σ2G',
#  'σ2G',
#  'σ2G',
#  'σ2G',
#  'σ2',
#  'σ2',
#  'σ-factor',
#  'σ-factor',
#  'σ-factor',
#  'σ-factor',
#  'σ',
#  'σ',
#  'σ',
#  'σ',
#  'σ',
#  'σ',
#  'σ',
#  'σ',
#  'ρi',
#  'ρG',
#  'ρG',
#  'ρG',
#  'ρG',
#  'ρG',
#  'ρG',
#  'ρE',
#  'ρ',
#  'ρ',
#  'ρ',
#  'ρ',
#  'πσi2e',
#  'πn',
#  'πi',
#  'πi',
#  'π200',
#  'π2',
#  'π2',
#  'π1',
#  'π1',
#  'π-cation',
#  'π-cation',
#  'π-cation',
#  'π-cation',
#  'π-cation',
#  'π-cation',
#  'π-cation',
#  'π-cation',
#  'π-cation',
#  'π-cation',
#  'π-cation',
#  'π',
#  'π',
#  'π',
#  'π',
#  'π',
#  'π',
#  'π',
#  'π',
#  'π',
#  'π',
#  'π',
#  'π',
#  'π',
#  'μm',
#  'μg',
#  'μg',
#  'μg',
#  'μg',
#  'μg',
#  'μg',
#  'μg',
#  'μg',
#  'μg',
#  'μg',
#  'μg',
#  'μg',
#  'μM',
#  'μM',
#  'μM',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μL',
#  'μ',
#  'μ',
#  'μ',
#  'μ',
#  'μ',
#  'μ',
#  'μ',
#  'μ',
#  'μ',
#  'μ',
#  'λΣ',
#  'λ2',
#  'λ2',
#  'λ1',
#  'λ1',
#  'λ1',
#  'λ1',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'λ',
#  'κb',
#  'κBζ',
#  'κBζ',
#  'κBζ',
#  'κBζ',
#  'κBζ',
#  'κBζ',
#  'κBζ',
#  'κB2',
#  'κB1',
#  'κB-regulated',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κB',
#  'κ-light-chain-enhancer',
#  'θjpi',
#  'θij',
#  'θij',
#  'θ',
#  'θ',
#  'θ',
#  'θ',
#  'θ',
#  'θ',
#  'ηπij',
#  'η',
#  'εi',
#  'εi',
#  'δS',
#  'δ-lactonic',
#  'δ-aminotransferase',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'δ',
#  'γp',
#  'γZ',
#  'γZ',
#  'γZ',
#  'γ4BMIi',
#  'γ4',
#  'γ4',
#  'γ3areai',
#  'γ3AREAi',
#  'γ3',
#  'γ3',
#  'γ3',
#  'γ2agei',
#  'γ2SEXi',
#  'γ2',
#  'γ2',
#  'γ2',
#  'γ2',
#  'γ2',
#  'γ1sexi',
#  'γ1AGEi',
#  'γ1',
#  'γ1',
#  'γ1',
#  'γ1',
#  'γ1',
#  'γ1',
#  'γ1',
#  'γ-treated',
#  'γ-rays',
#  'γ-rays',
#  'γ-rays',
#  'γ-rays',
#  'γ-rays',
#  'γ-irradiation',
#  'γ-irradiation',
#  'γ-interacting',
#  'γ-associated',
#  'γ-H2AX',
#  'γ-H2AX',
#  'γ-H2AX',
#  'γ-BRCA1',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'γ',
#  'βpχpi-γ1sexi-γ2agei-γ3areai2',
#  'βpχpi-γ1sexi-γ2agei-γ3areai2',
#  'βpxip',
#  'βp',
#  'βm',
#  'βkmk',
#  'βk2',
#  'βk2',
#  'βk1',
#  'βk',
#  'βk',
#  'βk',
#  'βk',
#  'βk',
#  'βjχq',
#  'βjχq',
#  'βj',
#  'βj',
#  'βj',
#  'βj',
#  'βj',
#  'βj',
#  'βj',
#  'βj',
#  'βj',
#  'βj',
#  'βj',
#  'βj',
#  'βiχp',
#  'βijχpχq',
#  'βiXp',
#  'βg2',
#  'βg',
#  'βfij',
#  'βfij',
#  'βc2',
#  'βc',
#  'β2SNP2',
#  'β2',
#  'β2',
#  'β2',
#  'β2',
#  'β2',
#  'β2',
#  'β2',
#  'β2',
#  'β1xi1',
#  'β1SNP1',
#  'β1-mediated',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β1',
#  'β0',
#  'β0',
#  'β0',
#  'β0',
#  'β0',
#  'β0',
#  'β0',
#  'β-unsaturated',
#  'β-unsaturated',
#  'β-treated',
#  'β-spectrin',
#  'β-responsive',
#  'β-proteobacterial',
#  'β-proteobacteria',
#  'β-oxidation',
#  'β-oxidation',
#  'β-mercaptoethanol',
#  'β-mediated',
#  'β-lactamase',
#  'β-ketobutyryl-were',
#  'β-ketobutyryl',
#  'β-ketobutyryl',
#  'β-ketobutyryl',
#  'β-ketobutyryl',
#  'β-ketoacyl',
#  'β-ketoacyl',
#  'β-ketoacyl',
#  'β-ketoacyl',
#  'β-ketoacyl',
#  'β-ketoacyl',
#  'β-ketoacyl',
#  'β-ketoacyl',
#  'β-ionone',
#  'β-ionone',
#  'β-induced',
#  'β-induced',
#  'β-hydroxy',
#  'β-globin',
#  'β-globin',
#  'β-globin',
#  'β-globin',
#  'β-globin',
#  'β-globin',
#  'β-galactosidase',
#  'β-galactosidase',
#  'β-galactosidase',
#  'β-fibrinogen',
#  'β-endorphin',
#  'β-endorphin',
#  'β-dependent',
#  'β-coefficients',
#  'β-coefficients',
#  'β-cells',
#  'β-cells',
#  'β-cells',
#  'β-cells',
#  'β-cells',
#  'β-cells',
#  'β-cells',
#  'β-cells',
#  'β-cells',
#  'β-cells',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-cell',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-catenin',
#  'β-caryophyllene',
#  'β-carbon',
#  'β-actin',
#  'β-actin',
#  'β-actin',
#  'β-actin',
#  'β-Ketoacyl',
#  'β-Galactosidase',
#  'β-2',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'β',
#  'αΣβ2',
#  'αijk',
#  'αijKi',
#  'αij2',
#  'αij1',
#  'αi',
#  'αi',
#  'αi',
#  'αi',
#  'αi',
#  'αi',
#  'αi',
#  'αi',
#  'αi',
#  'αi',
#  'αi',
#  'αi',
#  'αi',
#  'αi',
#  'αi',
#  'αSNP3',
#  'α6β6',
#  'α6',
#  'α5β1',
#  'α5',
#  'α5',
#  'α5',
#  'α5',
#  'α5',
#  'α5',
#  'α5',
#  'α5',
#  'α5',
#  'α5',
#  'α4',
#  'α4',
#  'α4',
#  'α4',
#  'α4',
#  'α4',
#  'α4',
#  'α4',
#  'α4',
#  'α2-Heremans-Schmid',
#  'α2',
#  'α2',
#  'α2',
#  'α2',
#  'α2',
#  'α1',
#  'α1',
#  'α1',
#  'α0',
#  'α0',
#  'α-subunit',
#  'α-subtree',
#  'α-ketoglutarate',
#  'α-inducible',
#  'α-helical',
#  'α-globin',
#  'α-amidating',
#  'α-actinin-3',
#  'α-PDBs',
#  'α-PDB',
#  'α-PDB',
#  'α-PDB',
#  'α-PDB',
#  'α-PDB',
#  'α-PDB',
#  'α-PDB',
#  'α-PDB',
#  'α-32P',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  'α',
#  ...]
